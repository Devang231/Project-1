# %%
import requests
import pandas as pd

url = 'https://api.eia.gov/v2/electricity/retail-sales/data/?frequency=monthly&data[0]=customers&data[1]=price&data[2]=revenue&data[3]=sales&facets[stateid][]=AZ&facets[stateid][]=CO&facets[stateid][]=NM&facets[stateid][]=UT&start=2016-01&end=2021-12&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000'


params = {
    'api_key': 'JwAMPFT7h0AWPe1W6aZPVE8EV01ThMMk88HF9IwA',
    'frequency': 'monthly',
    'data[0]': 'customers',
    'data[1]': 'price',
    'data[2]': 'revenue',
    'data[3]': 'sales',
    'start': '2016-01',
    'end': '2021-12',
    'sort[0][column]': 'period',
    'sort[0][direction]': 'desc',
    'offset': '0',
    'length': '5000'
}

response = requests.get(url, params=params)

print(json.dumps(response.json(),indent=4))
# Out:
# {
#     "response": {
#         "total": 1728,
#         "dateFormat": "YYYY-MM",
#         "frequency": "monthly",
#         "data": [
#             {
#                 "period": "2021-12",
#                 "stateid": "CO",
#                 "stateDescription": "Colorado",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "customers": 2866032,
#                 "price": 10.94,
#                 "revenue": 494.80521,
#                 "sales": 4521.59569,
#                 "customers-units": "number of customers",
#                 "price-units": "cents per kilowatthour",
#                 "revenue-units": "million dollars",
#                 "sales-units": "million kilowatthours"
#             },
#             {
#                 "period": "2021-12",
#                 "stateid": "UT",
#                 "stateDescription": "Utah",
#                 "sectorid": "IND",
#                 "sectorName": "industrial",
# ...
