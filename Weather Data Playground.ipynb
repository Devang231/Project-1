# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv("C:/Users/adina/Desktop/Classwork/Project 1/Project-1/Weather API Data CSVs/2022Mondays.csv")
df.head()
# Out:
#    datetime  tempmax  tempmin  temp  humidity  precipcover preciptype  \
# 0  1/3/2022     49.1     25.7  36.3      43.6          0.0        NaN
# 1  1/3/2022     21.5    -15.5   0.7      71.9          0.0        NaN
# 2  1/3/2022     49.8     25.8  36.4      42.3          0.0        NaN
# 3  1/3/2022     34.7      8.3  17.3      81.2          0.0        NaN
# 4  1/3/2022     48.0     19.2  31.9      50.9          0.0        NaN
#
#    cloudcover  solarradiation  solarenergy  uvindex  sunrise    sunset  \
# 0        72.1            99.0          8.5        4  7:19:08  16:44:59
# 1         0.0           152.5         12.9        5  7:18:24  16:57:21
# 2        71.9            75.8          6.6        4  7:18:28  16:45:39
# 3         0.2           199.7         17.3        8  7:22:28  17:03:24
# 4         0.0           129.8         11.3        5  7:04:40  16:45:04
#
#       County
# 0      Adams
# 1    Alamosa
# 2   Arapahoe
# 3  Archuleta
# 4       Baca

# %%
counties_df.groupby(['County'],as_index=False).mean().sort_values("cloudcover").plot.bar(x='County',y='cloudcover')
# Out:
# <AxesSubplot:xlabel='County'>

# %%
counties_df = df.groupby('County',as_index=False).mean()
x = counties_df['humidity']
y = counties_df['temp']
counties_df.plot(kind='scatter',x='humidity',y='temp')
slope, intercept, r, p, std_err = stats.linregress(x, y)
r
# Out:
# -0.5685416011911446
