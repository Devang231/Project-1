# %%
import requests
import json
import pandas as pd
import csv



url = "https://api.eia.gov/v2/electricity/electric-power-operational-data/data/"

# Set query parameters
params = {
    "frequency": "annual",
    "data[0]": "cost",
    "data[1]": "generation",
    "facets[location][]": "CO",
    "start": "2017",
    "end": "2022",
    "sort[0][column]": "period",
    "sort[0][direction]": "desc",
    "offset": "0",
    "length": "5000",
    "api_key": "0I8fsLv36n0dXGz5oyxBXIGW0mtgBapITdW8e9ql"
}

response = requests.get(url, params=params)

print(response.json())

data = response.json()
# Out:
# {'response': {'total': 1273, 'dateFormat': 'YYYY', 'frequency': 'annual', 'data': [{'period': 2022, 'location': 'CO', 'stateDescription': 'Colorado', 'sectorid': 2, 'sectorDescription': 'IPP Non-CHP', 'fueltypeid': 'AOR', 'fuelTypeDescription': 'all renewables', 'cost': None, 'cost-units': 'dollars per physical units', 'generation': 14736.24521, 'generation-units': 'thousand megawatthours'}, {'period': 2022, 'location': 'CO', 'stateDescription': 'Colorado', 'sectorid': 2, 'sectorDescription': 'IPP Non-CHP', 'fueltypeid': 'BIO', 'fuelTypeDescription': 'biomass', 'cost': None, 'cost-units': 'dollars per physical units', 'generation': 127.8208, 'generation-units': 'thousand megawatthours'}, {'period': 2022, 'location': 'CO', 'stateDescription': 'Colorado', 'sectorid': 2, 'sectorDescription': 'IPP Non-CHP', 'fueltypeid': 'DFO', 'fuelTypeDescription': 'distillate fuel oil', 'cost': None, 'cost-units': 'dollars per short tons', 'generation': 2.78693, 'generation-units': 'thousand megawatthours'}, {'period': 2022, 'location': 'CO', 'stateDescription': 'Colorado', 'sectorid': 2, 'sectorDescription': 'IPP Non-CHP', 'fueltypeid': 'FOS', 'fuelTypeDescription': 'fossil fuels', 'cost': None, 'cost-units': 'dollars per physical units', 'generation': 2215.71218, 'generation-units': 'thousand megawatthours'}, {'period': 2022, 'location': 'CO', 'stateDescription': 'Colorado', 'sectorid': 2, 'sectorDescription': 'IPP Non-CHP', 'fueltypeid': 'HYC', 'fuelTypeDescription': 'conventional hydroelectric', 'cost': None, 'cost-units': 'dollars per physical units', 'generation': 207.66949, 'generation-units': 'thousand megawatthours'}, {'period': 2022, 'location': 'CO', 'stateDescription': 'Colorado', 'sectorid': 2, 'sectorDescription': 'IPP Non-CHP', 'fueltypeid': 'LFG', 'fuelTypeDescription': 'landfill gas', 'cost': None, 'cost-units': 'dollars per physical units', 'generation': 37.4148, 'generation-units': 'thousand megawatthours'}, {'period': 2022, 'location': 'CO', 'stateDescription': 'Colorado', 'sectorid': 97, 'sectorDescription': 'All Industrial', 'fueltypeid': 'PEL', 'fuelTypeDescription': 'petroleum liquids', 'cost': None, 'cost-units': 'dollars per barrels', 'generation': 0.024, 'generation-units': 'thousand megawatthours'}, {'period': 2022, 'location': 'CO', 'stateDescription': 'Colorado', 'sectorid': 97, 'sectorDescription': 'All Industrial', 'fueltypeid': 'PET', 'fuelTypeDescription': 'petroleum', 'cost': None, 'cost-units': 'dollars per barrels', 'generation': 0.024, 'generation-units': 'thousand megawatthours'}, {'period': 2022, 'location': 'CO', 'stateDescription': 'Colorado', 'sectorid': 97, 'sectorDescription': 'All Industrial', 'fueltypeid': 'REN', 'fuelTypeDescription': 'renewable', 'cost': None, 'cost-units': 'dollars per physical units', 'generation': 2.253, 'generation-units': 'thousand megawatthours'}, {'period': 2022, 'location': 'CO', 'stateDescription': 'Colorado', 'sectorid': 97, 'sectorDescription': 'All Industrial', 'fueltypeid': 'SUB', 'fuelTypeDescription': 'subbituminous coal', 'cost': None, 'cost-units': 'dollars per short tons', 'generation': 0, 'generation-units': 'thousand megawatthours'}, {'period': 2022, 'location': 'CO', 'stateDescription': 'Colorado', 'sectorid': 97, 'sectorDescription': 'All Industrial', 'fueltypeid': 'TPV', 'fuelTypeDescription': 'estimated total solar photovoltaic', 'cost': 0, 'cost-units': 'dollars per physical units', 'generation': 22.80679, 'generation-units': 'thousand megawatthours'}, {'period': 2022, 'location': 'CO', 'stateDescription': 'Colorado', 'sectorid': 97, 'sectorDescription': 'All Industrial', 'fueltypeid': 'TSN', 'fuelTypeDescription': 'estimated total solar', 'cost': 0, 'cost-units': 'dollars per physical units', 'generation': 22.80679, 'generation-units': 'thousand megawatthours'}, {'period': 2022, 'location': 'CO', 'stateDescription': 'Colorado', 'sectorid': 97, 'sectorDescription': 'All Industrial', 'fueltypeid': 'WND', 'fuelTypeDescription': 'wind', 'cost': None, 'cost-u ...

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                                                       response  \
# total                                                     1273
# dateFormat                                                YYYY
# frequency                                               annual
# data         [{'period': 2022, 'location': 'CO', 'stateDesc...
# description  Monthly and annual electric power operations b...
# command                                                    NaN
# params                                                     NaN
#
#                                                        request apiVersion
# total                                                      NaN      2.1.4
# dateFormat                                                 NaN      2.1.4
# frequency                                                  NaN      2.1.4
# data                                                       NaN      2.1.4
# description                                                NaN      2.1.4
# command      /v2/electricity/electric-power-operational-dat...      2.1.4
# params       {'frequency': 'annual', 'data': ['cost', 'gene...      2.1.4

# %%
    # Write the data to a CSV file
    with open("newcensus_data.csv", "w", newline="") as csvfile:
        writer = csv.writer(csvfile)
        writer.writerows(data)
