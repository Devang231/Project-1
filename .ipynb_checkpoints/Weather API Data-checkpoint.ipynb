# %%
import requests
import json
import pandas as pd
from config import adina_api_key, henry_api_key, devang_api_key, tanner_api_key

# %%
#Reading in counties DF
counties = pd.read_csv('C:/Users/adina/Desktop/Classwork/Project 1/Project-1/CO County Data.csv',encoding='cp1252')
counties_df = pd.DataFrame(counties)
counties_df.head()
# Out:
#    FIPS     County  County Seat(s) Population (2010) Land Area km2  \
# 0  8001      Adams        Brighton           441,603      3,024.21
# 1  8003    Alamosa         Alamosa            15,445      1,871.64
# 2  8005   Arapahoe       Littleton           572,003      2,067.07
# 3  8007  Archuleta  Pagosa Springs            12,084      3,496.94
# 4  8009       Baca     Springfield             3,788      6,617.33
#
#   Land Area mi2  Water Area km2  Water Area mi2 Total Area km2 Total Area mi2  \
# 0      1,167.65          42.070          16.243       3,066.28       1,183.90
# 1       722.643           1.808           0.698       1,873.45        723.341
# 2         798.1          19.004           7.337       2,086.07        805.437
# 3      1,350.18          13.828           5.339       3,510.77       1,355.51
# 4      2,554.97           6.142           2.372       6,623.48       2,557.34
#
#     Latitude   Longitude
# 0  39.874325 -104.331872
# 1  37.568442 -105.788041
# 2  39.644632 -104.331733
# 3  37.202395 -107.050863
# 4  37.303144 -102.535457

# %%
# Create list of dates (Mondays in 2022)
# Following code adapted from: https://stackoverflow.com/questions/2003870/how-can-i-select-all-of-the-sundays-for-a-year-using-python

def allmondays(year):
    return pd.date_range(start=str(year), end=str(year+1), 
                         freq='W-MON').strftime('%Y-%m-%d').tolist()

dates = allmondays(2022)
dates
# Out:
# ['2022-01-03',
#  '2022-01-10',
#  '2022-01-17',
#  '2022-01-24',
#  '2022-01-31',
#  '2022-02-07',
#  '2022-02-14',
#  '2022-02-21',
#  '2022-02-28',
#  '2022-03-07',
#  '2022-03-14',
#  '2022-03-21',
#  '2022-03-28',
#  '2022-04-04',
#  '2022-04-11',
#  '2022-04-18',
#  '2022-04-25',
#  '2022-05-02',
#  '2022-05-09',
#  '2022-05-16',
#  '2022-05-23',
#  '2022-05-30',
#  '2022-06-06',
#  '2022-06-13',
#  '2022-06-20',
#  '2022-06-27',
#  '2022-07-04',
#  '2022-07-11',
#  '2022-07-18',
#  '2022-07-25',
#  '2022-08-01',
#  '2022-08-08',
#  '2022-08-15',
#  '2022-08-22',
#  '2022-08-29',
#  '2022-09-05',
#  '2022-09-12',
#  '2022-09-19',
#  '2022-09-26',
#  '2022-10-03',
#  '2022-10-10',
#  '2022-10-17',
#  '2022-10-24',
#  '2022-10-31',
#  '2022-11-07',
#  '2022-11-14',
#  '2022-11-21',
#  '2022-11-28',
#  '2022-12-05',
#  '2022-12-12',
#  '2022-12-19',
#  '2022-12-26']

# %%
#Dates ranges for batches
for date in dates[39:52]:
    print(date)
    
# 0-13
# 13-26
# 26-39
# 39-52
# Out:
# 2022-10-03
# 2022-10-10
# 2022-10-17
# 2022-10-24
# 2022-10-31
# 2022-11-07
# 2022-11-14
# 2022-11-21
# 2022-11-28
# 2022-12-05
# 2022-12-12
# 2022-12-19
# 2022-12-26

# %%
##USE THIS!##

weather_data = []

# loop through dates in chunks
for date in dates[39:52]:
    
    # for index, row in counties_weather_df.iterrows():
    for index, row in counties_df.iterrows():

    # Get latitude, longitude from the DataFrame
        latitude = row['Latitude']
        longitude = row['Longitude']
        request_date = date
        api_key = adina_api_key
        county = row['County']

            # Set base URL
        base_url = f'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/{latitude},{longitude}/{request_date}/{request_date}?key={api_key}&contentType=json&include=days&elements=cloudcover,datetime,solarradiation,solarenergy,tempmax,tempmin,temp,humidity,precipcover,preciptype,uvindex,sunrise,sunset'

            # Make an API request and convert to JSON
        response = requests.get(base_url).json()

        try:
            weather_dict = response['days'][0]
            weather_dict['County'] = county
            weather_data.append(weather_dict)
        except:
            pass

weather_data
# Out:
# [{'datetime': '2022-10-03',
#   'tempmax': 72.1,
#   'tempmin': 50.7,
#   'temp': 58.5,
#   'humidity': 65.7,
#   'precipcover': 20.83,
#   'preciptype': ['rain'],
#   'cloudcover': 77.0,
#   'solarradiation': 106.9,
#   'solarenergy': 9.1,
#   'uvindex': 7.0,
#   'sunrise': '06:55:37',
#   'sunset': '18:36:23',
#   'County': 'Adams'},
#  {'datetime': '2022-10-03',
#   'tempmax': 62.1,
#   'tempmin': 44.1,
#   'temp': 50.0,
#   'humidity': 80.8,
#   'precipcover': 20.83,
#   'preciptype': ['rain'],
#   'cloudcover': 73.4,
#   'solarradiation': 153.5,
#   'solarenergy': 13.4,
#   'uvindex': 6.0,
#   'sunrise': '07:00:30',
#   'sunset': '18:43:12',
#   'County': 'Alamosa'},
#  {'datetime': '2022-10-03',
#   'tempmax': 72.0,
#   'tempmin': 50.2,
#   'temp': 58.4,
#   'humidity': 66.4,
#   'precipcover': 20.83,
#   'preciptype': ['rain'],
#   'cloudcover': 76.3,
#   'solarradiation': 176.8,
#   'solarenergy': 15.2,
#   'uvindex': 7.0,
#   'sunrise': '06:55:31',
#   'sunset': '18:36:29',
#   'County': 'Arapahoe'},
#  {'datetime': '2022-10-03',
#   'tempmax': 57.7,
#   'tempmin': 44.8,
#   'temp': 49.8,
#   'humidity': 82.8,
#   'precipcover': 12.5,
#   'preciptype': ['rain'],
#   'cloudcover': 45.7,
#   'solarradiation': 131.8,
#   'solarenergy': 11.3,
#   'uvindex': 7.0,
#   'sunrise': '07:05:24',
#   'sunset': '18:48:24',
#   'County': 'Archuleta'},
#  {'datetime': '2022-10-03',
#   'tempmax': 83.9,
#   'tempmin': 55.1,
#   'temp': 67.7,
#   'humidity': 37.5,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 4.0,
#   'solarradiation': 219.7,
#   'solarenergy': 18.9,
#   'uvindex': 8.0,
#   'sunrise': '06:47:22',
#   'sunset': '18:30:19',
#   'County': 'Baca'},
#  {'datetime': '2022-10-03',
#   'tempmax': 81.8,
#   'tempmin': 55.9,
#   'temp': 66.4,
#   'humidity': 48.8,
#   'precipcover': 8.33,
#   'preciptype': ['rain'],
#   'cloudcover': 32.9,
#   'solarradiation': 194.0,
#   'solarenergy': 16.6,
#   'uvindex': 8.0,
#   'sunrise': '06:49:48',
#   'sunset': '18:32:13',
#   'County': 'Bent'},
#  {'datetime': '2022-10-03',
#   'tempmax': 66.9,
#   'tempmin': 46.9,
#   'temp': 53.9,
#   'humidity': 77.0,
#   'precipcover': 16.67,
#   'preciptype': ['rain'],
#   'cloudcover': 48.2,
#   'solarradiation': 131.5,
#   'solarenergy': 11.2,
#   'uvindex': 7.0,
#   'sunrise': '06:59:58',
#   'sunset': '18:40:33',
#   'County': 'Boulder'},
#  {'datetime': '2022-10-03',
#   'tempmax': 72.8,
#   'tempmin': 49.5,
#   'temp': 58.1,
#   'humidity': 66.7,
#   'precipcover': 20.83,
#   'preciptype': ['rain'],
#   'cloudcover': 50.8,
#   'solarradiation': 193.0,
#   'solarenergy': 16.5,
#   'uvindex': 8.0,
#   'sunrise': '06:58:32',
#   'sunset': '18:39:14',
#   'County': 'Broomfield'},
#  {'datetime': '2022-10-03',
#   'tempmax': 56.8,
#   'tempmin': 40.6,
#   'temp': 46.5,
#   'humidity': 60.9,
#   'precipcover': 12.5,
#   'preciptype': ['rain'],
#   'cloudcover': 53.1,
#   'solarradiation': 176.0,
#   'solarenergy': 15.0,
#   'uvindex': 7.0,
#   'sunrise': '07:03:05',
#   'sunset': '18:44:49',
#   'County': 'Chaffee'},
#  {'datetime': '2022-10-03',
#   'tempmax': 80.1,
#   'tempmin': 50.0,
#   'temp': 65.7,
#   'humidity': 40.5,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 14.2,
#   'solarradiation': 173.3,
#   'solarenergy': 15.1,
#   'uvindex': 7.0,
#   'sunrise': '06:48:16',
#   'sunset': '18:29:56',
#   'County': 'Cheyenne'},
#  {'datetime': '2022-10-03',
#   'tempmax': 38.4,
#   'tempmin': 28.9,
#   'temp': 31.6,
#   'humidity': 89.3,
#   'precipcover': 8.33,
#   'preciptype': ['rain', 'snow'],
#   'cloudcover': 94.0,
#   'solarradiation': 264.0,
#   'solarenergy': 23.4,
#   'uvindex': 9.0,
#   'sunrise': '07:00:54',
#   'sunset': '18:41:49',
#   'County': 'Clear Creek'},
#  {'datetime': '2022-10-03',
#   'tempmax': 55.5,
#   'tempmin': 41.4,
#   'temp': 46.1,
#   'humidity': 83.8,
#   'precipcover': 25.0,
#   'preciptype': ['rain'],
#   'cloudcover': 74.4,
#   'solarradiation': 215.2,
#   'solarenergy': 18.5,
#   'uvindex': 7.0,
#   'sunrise': '07:01:55',
#   'sunset': '18:44:54',
#   'County': 'Conejos'},
#  {'datetime': '2022-10-03',
#   'tempmax': 54.6,
#   'tempmin': 40.8,
#   'temp': 45.5,
#   'humidity': 75.6,
#   'precipcover': 16.67,
#   'preciptype': ['rain'],
#   'cloudcover': 69.3,
#   'solarradiation': 84.9,
#   'solarenergy': 7.4,
#   'uvindex': 5.0,
#   'sunrise': '06:58:57',
#   'sunset': '18:41:53',
#   'County': 'Costilla'},
#  {'datetime': '2022-10-03',
#   'tempmax': 79.6,
#   'tempmin': 52.1,
#   'temp': 63.7,
#   'humidity': 51.7,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 19.5,
#   'solarradiation': 162.1,
#   'solarenergy': 14.3,
#   'uvindex': 8.0,
#   'sunrise': '06:52:48',
#   'sunset': '18:34:53',
#   'County': 'Crowley'},
#  {'datetime': '2022-10-03',
#   'tempmax': 62.5,
#   'tempmin': 40.8,
#   'temp': 51.3,
#   'humidity': 65.7,
#   'precipcover': 12.5,
#   'preciptype': ['rain'],
#   'cloudcover': 22.4,
#   'solarradiation': 139.8,
#   'solarenergy': 12.0,
#   'uvindex': 7.0,
#   'sunrise': '06:59:03',
#   'sunset': '18:41:19',
#   'County': 'Custer'},
#  {'datetime': '2022-10-03',
#   'tempmax': 66.4,
#   'tempmin': 44.1,
#   'temp': 54.6,
#   'humidity': 74.6,
#   'precipcover': 8.33,
#   'preciptype': ['rain'],
#   'cloudcover': 20.0,
#   'solarradiation': 194.6,
#   'solarenergy': 16.6,
#   'uvindex': 7.0,
#   'sunrise': '07:09:20',
#   'sunset': '18:50:57',
#   'County': 'Delta'},
#  {'datetime': '2022-10-03',
#   'tempmax': 72.3,
#   'tempmin': 49.5,
#   'temp': 58.2,
#   'humidity': 67.5,
#   'precipcover': 20.83,
#   'preciptype': ['rain'],
#   'cloudcover': 76.0,
#   'solarradiation': 219.8,
#   'solarenergy': 19.0,
#   'uvindex': 7.0,
#   'sunrise': '06:57:46',
#   'sunset': '18:38:38',
#   'County': 'Denver'},
#  {'datetime': '2022-10-03',
#   'tempmax': 59.5,
#   'tempmin': 42.1,
#   'temp': 50.2,
#   'humidity': 76.3,
#   'precipcover': 4.17,
#   'preciptype': ['rain'],
#   'cloudcover': 33.2,
#   'solarradiation': 197.7,
#   'solarenergy': 16.9,
#   'uvindex': 7.0,
#   'sunrise': '07:11:33',
#   'sunset': '18:54:05',
#   'County': 'Dolores'},
#  {'datetime': '2022-10-03',
#   'tempmax': 67.1,
#   'tempmin': 45.1,
#   'temp': 54.9,
#   'humidity': 66.7,
#   'precipcover': 20.83,
#   'preciptype': ['rain'],
#   'cloudcover': 48.3,
#   'solarradiation': 202.8,
#   'solarenergy': 17.5,
#   'uvindex': 8.0,
#   'sunrise': '06:57:46',
#   'sunset': '18:39:00',
#   'County': 'Douglas'},
#  {'datetime': '2022-10-03',
#   'tempmax': 58.5,
#   'tempmin': 40.4,
#   'temp': 47.2,
#   'humidity': 82.6,
#   'precipcover': 25.0,
#   'preciptype': ['rain'],
#   'cloudcover': 76.4,
#   'solarradiation': 175.8,
#   'solarenergy': 15.2,
#   'uvindex': 8.0,
#   'sunrise': '07:04:58',
#   'sunset': '18:45:56',
#   'County': 'Eagle'},
#  {'datetime': '2022-10-03',
#   'tempmax': 67.2,
#   'tempmin': 43.0,
#   'temp': 54.5,
#   'humidity': 65.5,
#   'precipcover': 8.33,
#   'preciptype': ['rain'],
#   'cloudcover': 21.1,
#   'solarradiation': 142.8,
#   'solarenergy': 12.3,
#   'uvindex': 6.0,
#   'sunrise': '06:54:31',
#   'sunset': '18:35:47',
#   'County': 'Elbert'},
#  {'datetime': '2022-10-03',
#   'tempmax': 71.1,
#   'tempmin': 46.9,
#   'temp': 58.9,
#   'humidity': 51.8,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 65.7,
#   'solarradiation': 112.7,
#   'solarenergy': 9.9,
#   'uvindex': 6.0,
#   'sunrise': '06:55:58',
#   'sunset': '18:37:37',
#   'County': 'El Paso'},
#  {'datetime': '2022-10-03',
#   'tempmax': 67.9,
#   'tempmin': 49.0,
#   'temp': 57.5,
#   'humidity': 52.2,
#   'precipcover': 12.5,
#   'preciptype': ['rain'],
#   'cloudcover': 61.7,
#   'solarradiation': 180.8,
#   'solarenergy': 15.6,
#   'uvindex': 7.0,
#   'sunrise': '06:59:23',
#   'sunset': '18:41:21',
#   'County': 'Fremont'},
#  {'datetime': '2022-10-03',
#   'tempmax': 65.8,
#   'tempmin': 42.1,
#   'temp': 52.7,
#   'humidity': 74.8,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 29.8,
#   'solarradiation': 156.3,
#   'solarenergy': 13.3,
#   'uvindex': 7.0,
#   'sunrise': '07:09:49',
#   'sunset': '18:50:48',
#   'County': 'Garfield'},
#  {'datetime': '2022-10-03',
#   'tempmax': 43.5,
#   'tempmin': 31.8,
#   'temp': 35.9,
#   'humidity': 75.3,
#   'precipcover': 8.33,
#   'preciptype': ['rain', 'snow'],
#   'cloudcover': 94.0,
#   'solarradiation': 254.8,
#   'solarenergy': 22.4,
#   'uvindex': 7.0,
#   'sunrise': '07:00:24',
#   'sunset': '18:41:10',
#   'County': 'Gilpin'},
#  {'datetime': '2022-10-03',
#   'tempmax': 49.2,
#   'tempmin': 34.9,
#   'temp': 40.9,
#   'humidity': 83.9,
#   'precipcover': 8.33,
#   'preciptype': ['rain'],
#   'cloudcover': 80.8,
#   'solarradiation': 161.3,
#   'solarenergy': 14.0,
#   'uvindex': 7.0,
#   'sunrise': '07:02:47',
#   'sunset': '18:43:19',
#   'County': 'Grand'},
#  {'datetime': '2022-10-03',
#   'tempmax': 59.1,
#   'tempmin': 37.2,
#   'temp': 45.7,
#   'humidity': 81.1,
#   'precipcover': 8.33,
#   'preciptype': ['rain'],
#   'cloudcover': 63.2,
#   'solarradiation': 169.0,
#   'solarenergy': 14.6,
#   'uvindex': 8.0,
#   'sunrise': '07:06:06',
#   'sunset': '18:47:53',
#   'County': 'Gunnison'},
#  {'datetime': '2022-10-03',
#   'tempmax': 51.0,
#   'tempmin': 36.7,
#   'temp': 42.9,
#   'humidity': 80.8,
#   'precipcover': 12.5,
#   'preciptype': ['rain'],
#   'cloudcover': 53.7,
#   'solarradiation': 165.8,
#   'solarenergy': 14.3,
#   'uvindex': 10.0,
#   'sunrise': '07:06:59',
#   'sunset': '18:49:28',
#   'County': 'Hinsdale'},
#  {'datetime': '2022-10-03',
#   'tempmax': 53.9,
#   'tempmin': 41.3,
#   'temp': 46.7,
#   'humidity': 64.1,
#   'precipcover': 16.67,
#   'preciptype': ['rain'],
#   'cloudcover': 19.6,
#   'solarradiation': 140.9,
#   'solarenergy': 12.2,
#   'uvindex': 6.0,
#   'sunrise': '06:57:14',
#   'sunset': '18:39:50',
#   'County': 'Huerfano'},
#  {'datetime': '2022-10-03',
#   'tempmax': 53.7,
#   'tempmin': 32.3,
#   'temp': 43.6,
#   'humidity': 74.8,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 59.0,
#   'solarradiation': 123.0,
#   'solarenergy': 10.6,
#   'uvindex': 7.0,
#   'sunrise': '07:03:57',
#   'sunset': '18:44:01',
#   'County': 'Jackson'},
#  {'datetime': '2022-10-03',
#   'tempmax': 71.9,
#   'tempmin': 48.9,
#   'temp': 57.8,
#   'humidity': 67.3,
#   'precipcover': 25.0,
#   'preciptype': ['rain'],
#   'cloudcover': 68.4,
#   'solarradiation': 97.8,
#   'solarenergy': 8.4,
#   'uvindex': 6.0,
#   'sunrise': '06:59:09',
#   'sunset': '18:40:10',
#   'County': 'Jefferson'},
#  {'datetime': '2022-10-03',
#   'tempmax': 82.7,
#   'tempmin': 57.1,
#   'temp': 67.9,
#   'humidity': 47.6,
#   'precipcover': 8.33,
#   'preciptype': ['rain'],
#   'cloudcover': 35.8,
#   'solarradiation': 173.3,
#   'solarenergy': 15.1,
#   'uvindex': 7.0,
#   'sunrise': '06:48:41',
#   'sunset': '18:30:44',
#   'County': 'Kiowa'},
#  {'datetime': '2022-10-03',
#   'tempmax': 80.4,
#   'tempmin': 50.7,
#   'temp': 65.8,
#   'humidity': 40.4,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 15.6,
#   'solarradiation': 162.2,
#   'solarenergy': 14.0,
#   'uvindex': 6.0,
#   'sunrise': '06:48:27',
#   'sunset': '18:29:44',
#   'County': 'Kit Carson'},
#  {'datetime': '2022-10-03',
#   'tempmax': 51.1,
#   'tempmin': 30.9,
#   'temp': 40.4,
#   'humidity': 77.7,
#   'precipcover': 12.5,
#   'preciptype': ['rain'],
#   'cloudcover': 56.5,
#   'solarradiation': 142.2,
#   'solarenergy': 12.2,
#   'uvindex': 5.0,
#   'sunrise': '07:03:25',
#   'sunset': '18:44:44',
#   'County': 'Lake'},
#  {'datetime': '2022-10-03',
#   'tempmax': 64.3,
#   'tempmin': 48.1,
#   'temp': 54.8,
#   'humidity': 73.2,
#   'precipcover': 4.17,
#   'preciptype': ['rain'],
#   'cloudcover': 43.8,
#   'solarradiation': 142.1,
#   'solarenergy': 12.1,
#   'uvindex': 8.0,
#   'sunrise': '07:08:36',
#   'sunset': '18:51:31',
#   'County': 'La Plata'},
#  {'datetime': '2022-10-03',
#   'tempmax': 70.2,
#   'tempmin': 48.5,
#   'temp': 56.3,
#   'humidity': 72.1,
#   'precipcover': 20.83,
#   'preciptype': ['rain'],
#   'cloudcover': 56.1,
#   'solarradiation': 102.3,
#   'solarenergy': 8.7,
#   'uvindex': 5.0,
#   'sunrise': '07:00:33',
#   'sunset': '18:40:38',
#   'County': 'Larimer'},
#  {'datetime': '2022-10-03',
#   'tempmax': 71.2,
#   'tempmin': 52.6,
#   'temp': 58.4,
#   'humidity': 66.8,
#   'precipcover': 16.67,
#   'preciptype': ['rain'],
#   'cloudcover': 42.0,
#   'solarradiation': 128.0,
#   'solarenergy': 10.8,
#   'uvindex': 6.0,
#   'sunrise': '06:53:25',
#   'sunset': '18:36:20',
#   'County': 'Las Animas'},
#  {'datetime': '2022-10-03',
#   'tempmax': 70.7,
#   'tempmin': 43.5,
#   'temp': 56.7,
#   'humidity': 63.5,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 20.0,
#   'solarradiation': 196.5,
#   'solarenergy': 16.9,
#   'uvindex': 7.0,
#   'sunrise': '06:51:57',
#   'sunset': '18:33:29',
#   'County': 'Lincoln'},
#  {'datetime': '2022-10-03',
#   'tempmax': 69.6,
#   'tempmin': 48.0,
#   'temp': 57.0,
#   'humidity': 80.6,
#   'precipcover': 12.5,
#   'preciptype': ['rain'],
#   'cloudcover': 42.2,
#   'solarradiation': 102.7,
#   'solarenergy': 9.0,
#   'uvindex': 5.0,
#   'sunrise': '06:51:00',
#   'sunset': '18:31:03',
#   'County': 'Logan'},
#  {'datetime': '2022-10-03',
#   'tempmax': 67.8,
#   'tempmin': 47.8,
#   'temp': 57.4,
#   'humidity': 70.3,
#   'precipcover': 8.33,
#   'preciptype': ['rain'],
#   'cloudcover': 14.9,
#   'solarradiation': 206.9,
#   'solarenergy': 17.9,
#   'uvindex': 8.0,
#   'sunrise': '07:11:47',
#   'sunset': '18:53:16',
#   'County': 'Mesa'},
#  {'datetime': '2022-10-03',
#   'tempmax': 43.5,
#   'tempmin': 35.3,
#   'temp': 38.9,
#   'humidity': 91.5,
#   'precipcover': 12.5,
#   'preciptype': ['rain', 'snow'],
#   'cloudcover': 67.6,
#   'solarradiation': 165.8,
#   'solarenergy': 14.3,
#   'uvindex': 10.0,
#   'sunrise': '07:05:07',
#   'sunset': '18:47:44',
#   'County': 'Mineral'},
#  {'datetime': '2022-10-03',
#   'tempmax': 66.2,
#   'tempmin': 39.3,
#   'temp': 51.4,
#   'humidity': 68.8,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 42.2,
#   'solarradiation': 199.9,
#   'solarenergy': 17.3,
#   'uvindex': 8.0,
#   'sunrise': '07:11:25',
#   'sunset': '18:51:33',
#   'County': 'Moffat'},
#  {'datetime': '2022-10-03',
#   'tempmax': 65.1,
#   'tempmin': 44.9,
#   'temp': 54.7,
#   'humidity': 78.1,
#   'precipcover': 4.17,
#   'preciptype': ['rain'],
#   'cloudcover': 22.3,
#   'solarradiation': 198.0,
#   'solarenergy': 17.0,
#   'uvindex': 9.0,
#   'sunrise': '07:11:39',
#   'sunset': '18:54:31',
#   'County': 'Montezuma'},
#  {'datetime': '2022-10-03',
#   'tempmax': 64.6,
#   'tempmin': 42.1,
#   'temp': 52.4,
#   'humidity': 79.0,
#   'precipcover': 8.33,
#   'preciptype': ['rain'],
#   'cloudcover': 18.5,
#   'solarradiation': 57.0,
#   'solarenergy': 5.0,
#   'uvindex': 3.0,
#   'sunrise': '07:10:45',
#   'sunset': '18:52:44',
#   'County': 'Montrose'},
#  {'datetime': '2022-10-03',
#   'tempmax': 71.1,
#   'tempmin': 49.9,
#   'temp': 58.4,
#   'humidity': 71.2,
#   'precipcover': 16.67,
#   'preciptype': ['rain'],
#   'cloudcover': 34.8,
#   'solarradiation': 164.9,
#   'solarenergy': 14.3,
#   'uvindex': 8.0,
#   'sunrise': '06:53:41',
#   'sunset': '18:34:07',
#   'County': 'Morgan'},
#  {'datetime': '2022-10-03',
#   'tempmax': 79.0,
#   'tempmin': 51.6,
#   'temp': 63.4,
#   'humidity': 53.6,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 29.0,
#   'solarradiation': 172.9,
#   'solarenergy': 15.1,
#   'uvindex': 7.0,
#   'sunrise': '06:52:21',
#   'sunset': '18:34:48',
#   'County': 'Otero'},
#  {'datetime': '2022-10-03',
#   'tempmax': 57.8,
#   'tempmin': 38.0,
#   'temp': 46.2,
#   'humidity': 76.5,
#   'precipcover': 4.17,
#   'preciptype': ['rain'],
#   'cloudcover': 39.2,
#   'solarradiation': 152.2,
#   'solarenergy': 13.0,
#   'uvindex': 7.0,
#   'sunrise': '07:08:39',
#   'sunset': '18:50:51',
#   'County': 'Ouray'},
#  {'datetime': '2022-10-03',
#   'tempmax': 49.5,
#   'tempmin': 33.7,
#   'temp': 39.2,
#   'humidity': 74.4,
#   'precipcover': 16.67,
#   'preciptype': ['rain'],
#   'cloudcover': 55.7,
#   'solarradiation': 174.4,
#   'solarenergy': 14.9,
#   'uvindex': 9.0,
#   'sunrise': '07:00:51',
#   'sunset': '18:42:15',
#   'County': 'Park'},
#  {'datetime': '2022-10-03',
#   'tempmax': 71.4,
#   'tempmin': 46.7,
#   'temp': 59.5,
#   'humidity': 62.1,
#   'precipcover': 8.33,
#   'preciptype': ['rain'],
#   'cloudcover': 5.8,
#   'solarradiation': 96.2,
#   'solarenergy': 8.2,
#   'uvindex': 3.0,
#   'sunrise': '06:47:58',
#   'sunset': '18:28:07',
#   'County': 'Phillips'},
#  {'datetime': '2022-10-03',
#   'tempmax': 57.8,
#   'tempmin': 34.1,
#   'temp': 45.0,
#   'humidity': 79.5,
#   'precipcover': 12.5,
#   'preciptype': ['rain'],
#   'cloudcover': 52.6,
#   'solarradiation': 128.2,
#   'solarenergy': 10.9,
#   'uvindex': 6.0,
#   'sunrise': '07:05:41',
#   'sunset': '18:47:00',
#   'County': 'Pitkin'},
#  {'datetime': '2022-10-03',
#   'tempmax': 83.3,
#   'tempmin': 57.5,
#   'temp': 68.6,
#   'humidity': 45.0,
#   'precipcover': 8.33,
#   'preciptype': ['rain'],
#   'cloudcover': 33.0,
#   'solarradiation': 140.6,
#   'solarenergy': 12.1,
#   'uvindex': 7.0,
#   'sunrise': '06:47:04',
#   'sunset': '18:29:28',
#   'County': 'Prowers'},
#  {'datetime': '2022-10-03',
#   'tempmax': 77.8,
#   'tempmin': 46.3,
#   'temp': 62.3,
#   'humidity': 53.1,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 8.9,
#   'solarradiation': 154.5,
#   'solarenergy': 13.2,
#   'uvindex': 7.0,
#   'sunrise': '06:55:32',
#   'sunset': '18:37:45',
#   'County': 'Pueblo'},
#  {'datetime': '2022-10-03',
#   'tempmax': 64.5,
#   'tempmin': 39.6,
#   'temp': 50.6,
#   'humidity': 74.6,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 33.4,
#   'solarradiation': 171.4,
#   'solarenergy': 14.6,
#   'uvindex': 8.0,
#   'sunrise': '07:11:08',
#   'sunset': '18:51:48',
#   'County': 'Rio Blanco'},
#  {'datetime': '2022-10-03',
#   'tempmax': 48.0,
#   'tempmin': 35.6,
#   'temp': 41.6,
#   'humidity': 86.6,
#   'precipcover': 25.0,
#   'preciptype': ['rain'],
#   'cloudcover': 73.0,
#   'solarradiation': 194.2,
#   'solarenergy': 16.7,
#   'uvindex': 7.0,
#   'sunrise': '07:03:08',
#   'sunset': '18:45:53',
#   'County': 'Rio Grande'},
#  {'datetime': '2022-10-03',
#   'tempmax': 62.0,
#   'tempmin': 38.7,
#   'temp': 48.8,
#   'humidity': 77.2,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 53.8,
#   'solarradiation': 183.3,
#   'solarenergy': 16.0,
#   'uvindex': 10.0,
#   'sunrise': '07:06:29',
#   'sunset': '18:46:43',
#   'County': 'Routt'},
#  {'datetime': '2022-10-03',
#   'tempmax': 59.1,
#   'tempmin': 37.8,
#   'temp': 48.4,
#   'humidity': 78.4,
#   'precipcover': 16.67,
#   'preciptype': ['rain'],
#   'cloudcover': 43.7,
#   'solarradiation': 169.7,
#   'solarenergy': 14.7,
#   'uvindex': 6.0,
#   'sunrise': '07:02:31',
#   'sunset': '18:44:50',
#   'County': 'Saguache'},
#  {'datetime': '2022-10-03',
#   'tempmax': 56.3,
#   'tempmin': 36.1,
#   'temp': 45.3,
#   'humidity': 74.4,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 53.3,
#   'solarradiation': 165.2,
#   'solarenergy': 14.3,
#   'uvindex': 8.0,
#   'sunrise': '07:08:07',
#   'sunset': '18:50:38',
#   'County': 'San Juan'},
#  {'datetime': '2022-10-03',
#   'tempmax': 59.1,
#   'tempmin': 39.2,
#   'temp': 47.2,
#   'humidity': 76.0,
#   'precipcover': 8.33,
#   'preciptype': ['rain'],
#   'cloudcover': 36.1,
#   'solarradiation': 170.3,
#   'solarenergy': 14.7,
#   'uvindex': 7.0,
#   'sunrise': '07:11:14',
#   'sunset': '18:53:33',
#   'County': 'San Miguel'},
#  {'datetime': '2022-10-03',
#   'tempmax': 68.6,
#   'tempmin': 50.2,
#   'temp': 59.1,
#   'humidity': 63.8,
#   'precipcover': 8.33,
#   'preciptype': ['rain'],
#   'cloudcover': 21.9,
#   'solarradiation': 108.0,
#   'solarenergy': 9.4,
#   'uvindex': 4.0,
#   'sunrise': '06:48:08',
#   'sunset': '18:28:02',
#   'County': 'Sedgwick'},
#  {'datetime': '2022-10-03',
#   'tempmax': 44.4,
#   'tempmin': 34.2,
#   'temp': 36.8,
#   'humidity': 83.8,
#   'precipcover': 16.67,
#   'preciptype': ['rain', 'snow'],
#   'cloudcover': 76.2,
#   'solarradiation': 173.1,
#   'solarenergy': 14.8,
#   'uvindex': 8.0,
#   'sunrise': '07:02:44',
#   'sunset': '18:43:43',
#   'County': 'Summit'},
#  {'datetime': '2022-10-03',
#   'tempmax': 69.5,
#   'tempmin': 49.5,
#   'temp': 58.4,
#   'humidity': 50.2,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 63.0,
#   'solarradiation': 160.6,
#   'solarenergy': 13.7,
#   'uvindex': 8.0,
#   'sunrise': '06:58:36',
#   'sunset': '18:40:13',
#   'County': 'Teller'},
#  {'datetime': '2022-10-03',
#   'tempmax': 67.2,
#   'tempmin': 49.6,
#   'temp': 57.0,
#   'humidity': 77.4,
#   'precipcover': 8.33,
#   'preciptype': ['rain'],
#   'cloudcover': 36.9,
#   'solarradiation': 113.7,
#   'solarenergy': 9.7,
#   'uvindex': 4.0,
#   'sunrise': '06:51:09',
#   'sunset': '18:31:52',
#   'County': 'Washington'},
#  {'datetime': '2022-10-03',
#   'tempmax': 72.7,
#   'tempmin': 48.1,
#   'temp': 58.0,
#   'humidity': 70.1,
#   'precipcover': 25.0,
#   'preciptype': ['rain'],
#   'cloudcover': 56.0,
#   'solarradiation': 164.9,
#   'solarenergy': 14.3,
#   'uvindex': 8.0,
#   'sunrise': '06:56:07',
#   'sunset': '18:36:17',
#   'County': 'Weld'},
#  {'datetime': '2022-10-03',
#   'tempmax': 68.6,
#   'tempmin': 46.6,
#   'temp': 59.6,
#   'humidity': 56.3,
#   'precipcover': 4.17,
#   'preciptype': ['rain'],
#   'cloudcover': 24.1,
#   'solarradiation': 94.5,
#   'solarenergy': 8.0,
#   'uvindex': 5.0,
#   'sunrise': '06:48:01',
#   'sunset': '18:28:42',
#   'County': 'Yuma'},
#  {'datetime': '2022-10-10',
#   'tempmax': 74.0,
#   'tempmin': 45.4,
#   'temp': 59.4,
#   'humidity': 34.7,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 19.8,
#   'solarradiation': 121.2,
#   'solarenergy': 10.4,
#   'uvindex': 6.0,
#   'sunrise': '07:02:37',
#   'sunset': '18:25:20',
#   'County': 'Adams'},
#  {'datetime': '2022-10-10',
#   'tempmax': 64.5,
#   'tempmin': 25.9,
#   'temp': 45.2,
#   'humidity': 63.3,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 6.1,
#   'solarradiation': 241.8,
#   'solarenergy': 20.9,
#   'uvindex': 8.0,
#   'sunrise': '07:06:47',
#   'sunset': '18:32:52',
#   'County': 'Alamosa'},
#  {'datetime': '2022-10-10',
#   'tempmax': 73.5,
#   'tempmin': 45.0,
#   'temp': 59.0,
#   'humidity': 35.3,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 19.1,
#   'solarradiation': 160.9,
#   'solarenergy': 13.8,
#   'uvindex': 6.0,
#   'sunrise': '07:02:27',
#   'sunset': '18:25:31',
#   'County': 'Arapahoe'},
#  {'datetime': '2022-10-10',
#   'tempmax': 60.9,
#   'tempmin': 34.0,
#   'temp': 45.8,
#   'humidity': 74.0,
#   'precipcover': 0.0,
#   'preciptype': ['rain'],
#   'cloudcover': 10.5,
#   'solarradiation': 176.7,
#   'solarenergy': 15.5,
#   'uvindex': 7.0,
#   'sunrise': '07:11:35',
#   'sunset': '18:38:11',
#   'County': 'Archuleta'},
#  {'datetime': '2022-10-10',
#   'tempmax': 77.0,
#   'tempmin': 42.2,
#   'temp': 60.1,
#   'humidity': 51.4,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.0,
#   'solarradiation': 221.6,
#   'solarenergy': 19.1,
#   'uvindex': 8.0,
#   'sunrise': '06:53:35',
#   'sunset': '18:20:04',
#   'County': 'Baca'},
#  {'datetime': '2022-10-10',
#   'tempmax': 79.2,
#   'tempmin': 38.1,
#   'temp': 59.4,
#   'humidity': 40.4,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.0,
#   'solarradiation': 210.7,
#   'solarenergy': 18.0,
#   'uvindex': 7.0,
#   'sunrise': '06:56:11',
#   'sunset': '18:21:47',
#   'County': 'Bent'},
#  {'datetime': '2022-10-10',
#   'tempmax': 69.9,
#   'tempmin': 37.7,
#   'temp': 53.7,
#   'humidity': 46.0,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 9.9,
#   'solarradiation': 143.8,
#   'solarenergy': 12.6,
#   'uvindex': 7.0,
#   'sunrise': '07:07:03',
#   'sunset': '18:29:26',
#   'County': 'Boulder'},
#  {'datetime': '2022-10-10',
#   'tempmax': 77.1,
#   'tempmin': 42.6,
#   'temp': 59.6,
#   'humidity': 37.1,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 10.8,
#   'solarradiation': 216.6,
#   'solarenergy': 18.5,
#   'uvindex': 9.0,
#   'sunrise': '07:05:33',
#   'sunset': '18:28:10',
#   'County': 'Broomfield'},
#  {'datetime': '2022-10-10',
#   'tempmax': 55.4,
#   'tempmin': 40.1,
#   'temp': 46.3,
#   'humidity': 45.2,
#   'precipcover': 0.0,
#   'preciptype': ['snow'],
#   'cloudcover': 21.6,
#   'solarradiation': 176.1,
#   'solarenergy': 15.2,
#   'uvindex': 8.0,
#   'sunrise': '07:09:44',
#   'sunset': '18:34:08',
#   'County': 'Chaffee'},
#  {'datetime': '2022-10-10',
#   'tempmax': 78.2,
#   'tempmin': 41.0,
#   'temp': 60.0,
#   'humidity': 40.7,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.0,
#   'solarradiation': 206.5,
#   'solarenergy': 17.9,
#   'uvindex': 7.0,
#   'sunrise': '06:54:56',
#   'sunset': '18:19:13',
#   'County': 'Cheyenne'},
#  {'datetime': '2022-10-10',
#   'tempmax': 41.3,
#   'tempmin': 29.2,
#   'temp': 33.7,
#   'humidity': 56.5,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 29.6,
#   'solarradiation': 293.2,
#   'solarenergy': 25.6,
#   'uvindex': 8.0,
#   'sunrise': '07:07:50',
#   'sunset': '18:30:50',
#   'County': 'Clear Creek'},
#  {'datetime': '2022-10-10',
#   'tempmax': 58.8,
#   'tempmin': 28.0,
#   'temp': 42.9,
#   'humidity': 64.7,
#   'precipcover': 0.0,
#   'preciptype': ['rain'],
#   'cloudcover': 9.4,
#   'solarradiation': 256.3,
#   'solarenergy': 22.1,
#   'uvindex': 8.0,
#   'sunrise': '07:08:05',
#   'sunset': '18:34:41',
#   'County': 'Conejos'},
#  {'datetime': '2022-10-10',
#   'tempmax': 59.2,
#   'tempmin': 29.0,
#   'temp': 43.3,
#   'humidity': 64.9,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 6.9,
#   'solarradiation': 214.0,
#   'solarenergy': 18.5,
#   'uvindex': 9.0,
#   'sunrise': '07:05:08',
#   'sunset': '18:31:39',
#   'County': 'Costilla'},
#  {'datetime': '2022-10-10',
#   'tempmax': 78.3,
#   'tempmin': 40.4,
#   'temp': 58.2,
#   'humidity': 39.4,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.0,
#   'solarradiation': 194.9,
#   'solarenergy': 16.8,
#   'uvindex': 7.0,
#   'sunrise': '06:59:18',
#   'sunset': '18:24:20',
#   'County': 'Crowley'},
#  {'datetime': '2022-10-10',
#   'tempmax': 66.4,
#   'tempmin': 36.3,
#   'temp': 50.1,
#   'humidity': 50.1,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 5.9,
#   'solarradiation': 204.0,
#   'solarenergy': 17.7,
#   'uvindex': 9.0,
#   'sunrise': '07:05:30',
#   'sunset': '18:30:50',
#   'County': 'Custer'},
#  {'datetime': '2022-10-10',
#   'tempmax': 72.0,
#   'tempmin': 43.8,
#   'temp': 57.0,
#   'humidity': 45.5,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 1.7,
#   'solarradiation': 207.3,
#   'solarenergy': 17.9,
#   'uvindex': 8.0,
#   'sunrise': '07:16:01',
#   'sunset': '18:40:13',
#   'County': 'Delta'},
#  {'datetime': '2022-10-10',
#   'tempmax': 73.5,
#   'tempmin': 44.6,
#   'temp': 58.8,
#   'humidity': 35.9,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 18.9,
#   'solarradiation': 153.3,
#   'solarenergy': 13.2,
#   'uvindex': 7.0,
#   'sunrise': '07:04:44',
#   'sunset': '18:27:37',
#   'County': 'Denver'},
#  {'datetime': '2022-10-10',
#   'tempmax': 63.3,
#   'tempmin': 38.6,
#   'temp': 49.5,
#   'humidity': 61.3,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 11.7,
#   'solarradiation': 204.6,
#   'solarenergy': 17.5,
#   'uvindex': 8.0,
#   'sunrise': '07:17:53',
#   'sunset': '18:43:42',
#   'County': 'Dolores'},
#  {'datetime': '2022-10-10',
#   'tempmax': 68.9,
#   'tempmin': 41.1,
#   'temp': 54.7,
#   'humidity': 39.0,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 18.3,
#   'solarradiation': 195.5,
#   'solarenergy': 16.9,
#   'uvindex': 8.0,
#   'sunrise': '07:04:35',
#   'sunset': '18:28:08',
#   'County': 'Douglas'},
#  {'datetime': '2022-10-10',
#   'tempmax': 63.1,
#   'tempmin': 32.8,
#   'temp': 46.9,
#   'humidity': 54.1,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 15.0,
#   'solarradiation': 143.5,
#   'solarenergy': 12.3,
#   'uvindex': 7.0,
#   'sunrise': '07:11:53',
#   'sunset': '18:34:58',
#   'County': 'Eagle'},
#  {'datetime': '2022-10-10',
#   'tempmax': 68.9,
#   'tempmin': 40.8,
#   'temp': 54.3,
#   'humidity': 39.3,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 17.1,
#   'solarradiation': 187.1,
#   'solarenergy': 16.2,
#   'uvindex': 7.0,
#   'sunrise': '07:01:21',
#   'sunset': '18:24:55',
#   'County': 'Elbert'},
#  {'datetime': '2022-10-10',
#   'tempmax': 72.5,
#   'tempmin': 41.8,
#   'temp': 56.3,
#   'humidity': 38.0,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 20.0,
#   'solarradiation': 144.3,
#   'solarenergy': 12.6,
#   'uvindex': 7.0,
#   'sunrise': '07:02:38',
#   'sunset': '18:26:55',
#   'County': 'El Paso'},
#  {'datetime': '2022-10-10',
#   'tempmax': 70.0,
#   'tempmin': 39.5,
#   'temp': 55.4,
#   'humidity': 38.7,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 21.3,
#   'solarradiation': 212.4,
#   'solarenergy': 18.2,
#   'uvindex': 8.0,
#   'sunrise': '07:05:56',
#   'sunset': '18:30:46',
#   'County': 'Fremont'},
#  {'datetime': '2022-10-10',
#   'tempmax': 69.9,
#   'tempmin': 37.8,
#   'temp': 52.0,
#   'humidity': 57.8,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 8.2,
#   'solarradiation': 100.4,
#   'solarenergy': 8.6,
#   'uvindex': 8.0,
#   'sunrise': '07:16:44',
#   'sunset': '18:39:51',
#   'County': 'Garfield'},
#  {'datetime': '2022-10-10',
#   'tempmax': 53.0,
#   'tempmin': 31.6,
#   'temp': 40.9,
#   'humidity': 49.2,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 21.3,
#   'solarradiation': 291.4,
#   'solarenergy': 25.2,
#   'uvindex': 8.0,
#   'sunrise': '07:07:24',
#   'sunset': '18:30:08',
#   'County': 'Gilpin'},
#  {'datetime': '2022-10-10',
#   'tempmax': 58.4,
#   'tempmin': 26.3,
#   'temp': 40.8,
#   'humidity': 56.2,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 35.4,
#   'solarradiation': 158.8,
#   'solarenergy': 13.7,
#   'uvindex': 7.0,
#   'sunrise': '07:09:52',
#   'sunset': '18:32:12',
#   'County': 'Grand'},
#  {'datetime': '2022-10-10',
#   'tempmax': 62.5,
#   'tempmin': 27.8,
#   'temp': 44.4,
#   'humidity': 58.6,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 6.1,
#   'solarradiation': 189.4,
#   'solarenergy': 16.2,
#   'uvindex': 7.0,
#   'sunrise': '07:12:44',
#   'sunset': '18:37:13',
#   'County': 'Gunnison'},
#  {'datetime': '2022-10-10',
#   'tempmax': 52.7,
#   'tempmin': 34.6,
#   'temp': 42.8,
#   'humidity': 61.6,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 17.6,
#   'solarradiation': 230.4,
#   'solarenergy': 19.9,
#   'uvindex': 10.0,
#   'sunrise': '07:13:20',
#   'sunset': '18:39:04',
#   'County': 'Hinsdale'},
#  {'datetime': '2022-10-10',
#   'tempmax': 60.3,
#   'tempmin': 36.4,
#   'temp': 47.0,
#   'humidity': 56.3,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 5.4,
#   'solarradiation': 135.3,
#   'solarenergy': 11.7,
#   'uvindex': 7.0,
#   'sunrise': '07:03:33',
#   'sunset': '18:29:28',
#   'County': 'Huerfano'},
#  {'datetime': '2022-10-10',
#   'tempmax': 61.0,
#   'tempmin': 21.6,
#   'temp': 40.6,
#   'humidity': 53.6,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 11.7,
#   'solarradiation': 184.2,
#   'solarenergy': 15.8,
#   'uvindex': 6.0,
#   'sunrise': '07:11:12',
#   'sunset': '18:32:43',
#   'County': 'Jackson'},
#  {'datetime': '2022-10-10',
#   'tempmax': 73.0,
#   'tempmin': 43.8,
#   'temp': 58.4,
#   'humidity': 36.5,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 15.5,
#   'solarradiation': 89.4,
#   'solarenergy': 7.7,
#   'uvindex': 4.0,
#   'sunrise': '07:06:04',
#   'sunset': '18:29:13',
#   'County': 'Jefferson'},
#  {'datetime': '2022-10-10',
#   'tempmax': 80.2,
#   'tempmin': 36.9,
#   'temp': 60.2,
#   'humidity': 40.8,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.0,
#   'solarradiation': 206.5,
#   'solarenergy': 17.9,
#   'uvindex': 7.0,
#   'sunrise': '06:55:13',
#   'sunset': '18:20:09',
#   'County': 'Kiowa'},
#  {'datetime': '2022-10-10',
#   'tempmax': 78.3,
#   'tempmin': 42.3,
#   'temp': 60.1,
#   'humidity': 40.3,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.0,
#   'solarradiation': 195.6,
#   'solarenergy': 16.8,
#   'uvindex': 7.0,
#   'sunrise': '06:55:16',
#   'sunset': '18:18:52',
#   'County': 'Kit Carson'},
#  {'datetime': '2022-10-10',
#   'tempmax': 50.0,
#   'tempmin': 24.4,
#   'temp': 37.6,
#   'humidity': 61.2,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 22.1,
#   'solarradiation': 167.9,
#   'solarenergy': 14.5,
#   'uvindex': 6.0,
#   'sunrise': '07:10:12',
#   'sunset': '18:33:55',
#   'County': 'Lake'},
#  {'datetime': '2022-10-10',
#   'tempmax': 64.7,
#   'tempmin': 37.6,
#   'temp': 50.2,
#   'humidity': 68.4,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 9.2,
#   'solarradiation': 133.8,
#   'solarenergy': 11.7,
#   'uvindex': 7.0,
#   'sunrise': '07:14:48',
#   'sunset': '18:41:16',
#   'County': 'La Plata'},
#  {'datetime': '2022-10-10',
#   'tempmax': 74.4,
#   'tempmin': 38.3,
#   'temp': 56.7,
#   'humidity': 43.3,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 4.7,
#   'solarradiation': 156.3,
#   'solarenergy': 13.4,
#   'uvindex': 6.0,
#   'sunrise': '07:07:49',
#   'sunset': '18:29:20',
#   'County': 'Larimer'},
#  {'datetime': '2022-10-10',
#   'tempmax': 73.1,
#   'tempmin': 40.3,
#   'temp': 57.0,
#   'humidity': 48.4,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.0,
#   'solarradiation': 225.0,
#   'solarenergy': 19.4,
#   'uvindex': 8.0,
#   'sunrise': '06:59:38',
#   'sunset': '18:26:05',
#   'County': 'Las Animas'},
#  {'datetime': '2022-10-10',
#   'tempmax': 72.1,
#   'tempmin': 37.7,
#   'temp': 54.5,
#   'humidity': 41.1,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 2.1,
#   'solarradiation': 214.1,
#   'solarenergy': 18.5,
#   'uvindex': 7.0,
#   'sunrise': '06:58:40',
#   'sunset': '18:22:43',
#   'County': 'Lincoln'},
#  {'datetime': '2022-10-10',
#   'tempmax': 78.7,
#   'tempmin': 34.0,
#   'temp': 54.3,
#   'humidity': 52.7,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 1.9,
#   'solarradiation': 194.6,
#   'solarenergy': 17.0,
#   'uvindex': 7.0,
#   'sunrise': '06:58:17',
#   'sunset': '18:19:43',
#   'County': 'Logan'},
#  {'datetime': '2022-10-10',
#   'tempmax': 72.2,
#   'tempmin': 47.6,
#   'temp': 58.9,
#   'humidity': 47.0,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 1.2,
#   'solarradiation': 207.2,
#   'solarenergy': 17.9,
#   'uvindex': 7.0,
#   'sunrise': '07:18:31',
#   'sunset': '18:42:29',
#   'County': 'Mesa'},
#  {'datetime': '2022-10-10',
#   'tempmax': 47.6,
#   'tempmin': 32.5,
#   'temp': 38.2,
#   'humidity': 73.7,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 16.3,
#   'solarradiation': 230.5,
#   'solarenergy': 19.9,
#   'uvindex': 10.0,
#   'sunrise': '07:11:25',
#   'sunset': '18:37:23',
#   'County': 'Mineral'},
#  {'datetime': '2022-10-10',
#   'tempmax': 69.3,
#   'tempmin': 33.2,
#   'temp': 49.8,
#   'humidity': 54.1,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 7.0,
#   'solarradiation': 221.8,
#   'solarenergy': 19.3,
#   'uvindex': 8.0,
#   'sunrise': '07:18:39',
#   'sunset': '18:40:16',
#   'County': 'Moffat'},
#  {'datetime': '2022-10-10',
#   'tempmax': 69.3,
#   'tempmin': 38.6,
#   'temp': 51.8,
#   'humidity': 71.9,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 5.8,
#   'solarradiation': 202.0,
#   'solarenergy': 17.6,
#   'uvindex': 7.0,
#   'sunrise': '07:17:51',
#   'sunset': '18:44:15',
#   'County': 'Montezuma'},
#  {'datetime': '2022-10-10',
#   'tempmax': 69.4,
#   'tempmin': 41.8,
#   'temp': 55.3,
#   'humidity': 50.3,
#   'precipcover': 0.0,
#   'preciptype': ['rain'],
#   'cloudcover': 0.8,
#   'solarradiation': 142.4,
#   'solarenergy': 12.4,
#   'uvindex': 8.0,
#   'sunrise': '07:17:17',
#   'sunset': '18:42:09',
#   'County': 'Montrose'},
#  {'datetime': '2022-10-10',
#   'tempmax': 76.9,
#   'tempmin': 37.5,
#   'temp': 57.5,
#   'humidity': 44.1,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 16.0,
#   'solarradiation': 229.3,
#   'solarenergy': 19.6,
#   'uvindex': 8.0,
#   'sunrise': '07:00:48',
#   'sunset': '18:22:57',
#   'County': 'Morgan'},
#  {'datetime': '2022-10-10',
#   'tempmax': 78.9,
#   'tempmin': 36.9,
#   'temp': 56.4,
#   'humidity': 43.8,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.0,
#   'solarradiation': 209.3,
#   'solarenergy': 17.9,
#   'uvindex': 7.0,
#   'sunrise': '06:58:44',
#   'sunset': '18:24:23',
#   'County': 'Otero'},
#  {'datetime': '2022-10-10',
#   'tempmax': 60.0,
#   'tempmin': 37.3,
#   'temp': 48.2,
#   'humidity': 51.7,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 14.0,
#   'solarradiation': 164.4,
#   'solarenergy': 14.1,
#   'uvindex': 8.0,
#   'sunrise': '07:15:07',
#   'sunset': '18:40:21',
#   'County': 'Ouray'},
#  {'datetime': '2022-10-10',
#   'tempmax': 49.2,
#   'tempmin': 33.2,
#   'temp': 39.7,
#   'humidity': 49.5,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 17.5,
#   'solarradiation': 191.2,
#   'solarenergy': 16.6,
#   'uvindex': 9.0,
#   'sunrise': '07:07:36',
#   'sunset': '18:31:27',
#   'County': 'Park'},
#  {'datetime': '2022-10-10',
#   'tempmax': 83.8,
#   'tempmin': 37.3,
#   'temp': 60.0,
#   'humidity': 44.5,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.0,
#   'solarradiation': 168.3,
#   'solarenergy': 14.6,
#   'uvindex': 6.0,
#   'sunrise': '06:55:12',
#   'sunset': '18:16:51',
#   'County': 'Phillips'},
#  {'datetime': '2022-10-10',
#   'tempmax': 62.9,
#   'tempmin': 33.1,
#   'temp': 46.4,
#   'humidity': 54.4,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 4.5,
#   'solarradiation': 190.6,
#   'solarenergy': 16.5,
#   'uvindex': 7.0,
#   'sunrise': '07:12:28',
#   'sunset': '18:36:10',
#   'County': 'Pitkin'},
#  {'datetime': '2022-10-10',
#   'tempmax': 80.3,
#   'tempmin': 37.3,
#   'temp': 60.5,
#   'humidity': 42.6,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.0,
#   'solarradiation': 191.1,
#   'solarenergy': 16.5,
#   'uvindex': 7.0,
#   'sunrise': '06:53:28',
#   'sunset': '18:19:01',
#   'County': 'Prowers'},
#  {'datetime': '2022-10-10',
#   'tempmax': 78.7,
#   'tempmin': 40.9,
#   'temp': 58.2,
#   'humidity': 39.3,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.2,
#   'solarradiation': 191.1,
#   'solarenergy': 16.5,
#   'uvindex': 7.0,
#   'sunrise': '07:02:01',
#   'sunset': '18:27:15',
#   'County': 'Pueblo'},
#  {'datetime': '2022-10-10',
#   'tempmax': 68.4,
#   'tempmin': 33.8,
#   'temp': 49.6,
#   'humidity': 58.6,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 4.2,
#   'solarradiation': 214.1,
#   'solarenergy': 18.5,
#   'uvindex': 7.0,
#   'sunrise': '07:18:10',
#   'sunset': '18:40:43',
#   'County': 'Rio Blanco'},
#  {'datetime': '2022-10-10',
#   'tempmax': 52.3,
#   'tempmin': 31.8,
#   'temp': 40.8,
#   'humidity': 65.3,
#   'precipcover': 0.0,
#   'preciptype': ['snow'],
#   'cloudcover': 13.2,
#   'solarradiation': 252.8,
#   'solarenergy': 21.8,
#   'uvindex': 8.0,
#   'sunrise': '07:09:23',
#   'sunset': '18:35:35',
#   'County': 'Rio Grande'},
#  {'datetime': '2022-10-10',
#   'tempmax': 66.4,
#   'tempmin': 32.2,
#   'temp': 48.3,
#   'humidity': 49.0,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 22.1,
#   'solarradiation': 163.8,
#   'solarenergy': 14.0,
#   'uvindex': 7.0,
#   'sunrise': '07:13:42',
#   'sunset': '18:35:28',
#   'County': 'Routt'},
#  {'datetime': '2022-10-10',
#   'tempmax': 64.3,
#   'tempmin': 32.3,
#   'temp': 48.1,
#   'humidity': 53.6,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 9.5,
#   'solarradiation': 251.2,
#   'solarenergy': 21.5,
#   'uvindex': 10.0,
#   'sunrise': '07:08:57',
#   'sunset': '18:34:22',
#   'County': 'Saguache'},
#  {'datetime': '2022-10-10',
#   'tempmax': 57.8,
#   'tempmin': 35.8,
#   'temp': 45.8,
#   'humidity': 53.9,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 18.6,
#   'solarradiation': 183.0,
#   'solarenergy': 15.8,
#   'uvindex': 8.0,
#   'sunrise': '07:14:28',
#   'sunset': '18:40:14',
#   'County': 'San Juan'},
#  {'datetime': '2022-10-10',
#   'tempmax': 60.6,
#   'tempmin': 37.3,
#   'temp': 48.5,
#   'humidity': 53.9,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 13.1,
#   'solarradiation': 201.0,
#   'solarenergy': 17.3,
#   'uvindex': 9.0,
#   'sunrise': '07:17:39',
#   'sunset': '18:43:06',
#   'County': 'San Miguel'},
#  {'datetime': '2022-10-10',
#   'tempmax': 81.3,
#   'tempmin': 36.0,
#   'temp': 58.0,
#   'humidity': 47.2,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 2.8,
#   'solarradiation': 200.3,
#   'solarenergy': 17.3,
#   'uvindex': 7.0,
#   'sunrise': '06:55:27',
#   'sunset': '18:16:40',
#   'County': 'Sedgwick'},
#  {'datetime': '2022-10-10',
#   'tempmax': 46.2,
#   'tempmin': 34.6,
#   'temp': 38.4,
#   'humidity': 55.1,
#   'precipcover': 0.0,
#   'preciptype': ['snow'],
#   'cloudcover': 28.7,
#   'solarradiation': 168.8,
#   'solarenergy': 14.5,
#   'uvindex': 6.0,
#   'sunrise': '07:09:39',
#   'sunset': '18:32:45',
#   'County': 'Summit'},
#  {'datetime': '2022-10-10',
#   'tempmax': 70.2,
#   'tempmin': 42.2,
#   'temp': 56.0,
#   'humidity': 37.1,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 24.6,
#   'solarradiation': 207.6,
#   'solarenergy': 18.0,
#   'uvindex': 9.0,
#   'sunrise': '07:05:17',
#   'sunset': '18:29:30',
#   'County': 'Teller'},
#  {'datetime': '2022-10-10',
#   'tempmax': 76.9,
#   'tempmin': 41.3,
#   'temp': 59.1,
#   'humidity': 40.0,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 4.3,
#   'solarradiation': 189.4,
#   'solarenergy': 16.4,
#   'uvindex': 7.0,
#   'sunrise': '06:58:11',
#   'sunset': '18:20:47',
#   'County': 'Washington'},
#  {'datetime': '2022-10-10',
#   'tempmax': 77.2,
#   'tempmin': 37.5,
#   'temp': 56.8,
#   'humidity': 45.3,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 6.0,
#   'solarradiation': 207.4,
#   'solarenergy': 17.8,
#   'uvindex': 7.0,
#   'sunrise': '07:03:20',
#   'sunset': '18:25:01',
#   'County': 'Weld'},
#  {'datetime': '2022-10-10',
#   'tempmax': 81.2,
#   'tempmin': 37.0,
#   'temp': 60.7,
#   'humidity': 39.0,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 1.2,
#   'solarradiation': 197.5,
#   'solarenergy': 17.1,
#   'uvindex': 7.0,
#   'sunrise': '06:55:04',
#   'sunset': '18:17:37',
#   'County': 'Yuma'},
#  {'datetime': '2022-10-17',
#   'tempmax': 61.9,
#   'tempmin': 34.9,
#   'temp': 46.9,
#   'humidity': 51.3,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 13.7,
#   'solarradiation': 181.5,
#   'solarenergy': 15.8,
#   'uvindex': 7.0,
#   'sunrise': '07:09:52',
#   'sunset': '18:14:49',
#   'County': 'Adams'},
#  {'datetime': '2022-10-17',
#   'tempmax': 59.3,
#   'tempmin': 21.7,
#   'temp': 39.8,
#   'humidity': 66.7,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 1.2,
#   'solarradiation': 259.6,
#   'solarenergy': 22.4,
#   'uvindex': 7.0,
#   'sunrise': '07:13:19',
#   'sunset': '18:23:04',
#   'County': 'Alamosa'},
#  {'datetime': '2022-10-17',
#   'tempmax': 61.4,
#   'tempmin': 34.5,
#   'temp': 47.0,
#   'humidity': 52.2,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 14.0,
#   'solarradiation': 137.3,
#   'solarenergy': 12.0,
#   'uvindex': 6.0,
#   'sunrise': '07:09:37',
#   'sunset': '18:15:04',
#   'County': 'Arapahoe'},
#  {'datetime': '2022-10-17',
#   'tempmax': 57.4,
#   'tempmin': 32.0,
#   'temp': 44.2,
#   'humidity': 73.9,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 19.3,
#   'solarradiation': 195.2,
#   'solarenergy': 16.7,
#   'uvindex': 7.0,
#   'sunrise': '07:18:01',
#   'sunset': '18:28:29',
#   'County': 'Archuleta'},
#  {'datetime': '2022-10-17',
#   'tempmax': 64.1,
#   'tempmin': 30.0,
#   'temp': 47.1,
#   'humidity': 55.5,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.0,
#   'solarradiation': 190.5,
#   'solarenergy': 16.5,
#   'uvindex': 7.0,
#   'sunrise': '07:00:02',
#   'sunset': '18:10:20',
#   'County': 'Baca'},
#  {'datetime': '2022-10-17',
#   'tempmax': 64.2,
#   'tempmin': 29.9,
#   'temp': 47.0,
#   'humidity': 53.9,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 4.6,
#   'solarradiation': 190.8,
#   'solarenergy': 16.6,
#   'uvindex': 7.0,
#   'sunrise': '07:02:50',
#   'sunset': '18:11:52',
#   'County': 'Bent'},
#  {'datetime': '2022-10-17',
#   'tempmax': 59.2,
#   'tempmin': 32.3,
#   'temp': 44.5,
#   'humidity': 59.3,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.0,
#   'solarradiation': 170.5,
#   'solarenergy': 14.8,
#   'uvindex': 6.0,
#   'sunrise': '07:14:22',
#   'sunset': '18:18:51',
#   'County': 'Boulder'},
#  {'datetime': '2022-10-17',
#   'tempmax': 64.9,
#   'tempmin': 36.0,
#   'temp': 49.1,
#   'humidity': 49.8,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.9,
#   'solarradiation': 178.9,
#   'solarenergy': 15.2,
#   'uvindex': 7.0,
#   'sunrise': '07:12:50',
#   'sunset': '18:17:37',
#   'County': 'Broomfield'},
#  {'datetime': '2022-10-17',
#   'tempmax': 55.6,
#   'tempmin': 31.4,
#   'temp': 41.6,
#   'humidity': 56.1,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 7.6,
#   'solarradiation': 187.5,
#   'solarenergy': 16.1,
#   'uvindex': 7.0,
#   'sunrise': '07:16:38',
#   'sunset': '18:23:58',
#   'County': 'Chaffee'},
#  {'datetime': '2022-10-17',
#   'tempmax': 64.1,
#   'tempmin': 28.1,
#   'temp': 44.1,
#   'humidity': 51.8,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 1.1,
#   'solarradiation': 191.3,
#   'solarenergy': 16.4,
#   'uvindex': 7.0,
#   'sunrise': '07:01:52',
#   'sunset': '18:09:02',
#   'County': 'Cheyenne'},
#  {'datetime': '2022-10-17',
#   'tempmax': 37.7,
#   'tempmin': 27.0,
#   'temp': 31.6,
#   'humidity': 55.8,
#   'precipcover': 4.17,
#   'preciptype': ['rain', 'snow'],
#   'cloudcover': 9.2,
#   'solarradiation': 208.0,
#   'solarenergy': 18.4,
#   'uvindex': 7.0,
#   'sunrise': '07:15:02',
#   'sunset': '18:20:22',
#   'County': 'Clear Creek'},
#  {'datetime': '2022-10-17',
#   'tempmax': 55.3,
#   'tempmin': 23.4,
#   'temp': 38.4,
#   'humidity': 66.8,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 11.0,
#   'solarradiation': 81.0,
#   'solarenergy': 6.9,
#   'uvindex': 1.0,
#   'sunrise': '07:14:31',
#   'sunset': '18:24:58',
#   'County': 'Conejos'},
#  {'datetime': '2022-10-17',
#   'tempmax': 51.8,
#   'tempmin': 24.3,
#   'temp': 37.2,
#   'humidity': 72.0,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 2.5,
#   'solarradiation': 247.2,
#   'solarenergy': 21.3,
#   'uvindex': 10.0,
#   'sunrise': '07:11:36',
#   'sunset': '18:21:55',
#   'County': 'Costilla'},
#  {'datetime': '2022-10-17',
#   'tempmax': 64.7,
#   'tempmin': 33.0,
#   'temp': 47.8,
#   'humidity': 54.4,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 4.9,
#   'solarradiation': 184.9,
#   'solarenergy': 16.1,
#   'uvindex': 7.0,
#   'sunrise': '07:06:04',
#   'sunset': '18:14:18',
#   'County': 'Crowley'},
#  {'datetime': '2022-10-17',
#   'tempmax': 57.5,
#   'tempmin': 31.3,
#   'temp': 43.2,
#   'humidity': 60.5,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 6.7,
#   'solarradiation': 156.4,
#   'solarenergy': 13.3,
#   'uvindex': 9.0,
#   'sunrise': '07:12:12',
#   'sunset': '18:20:52',
#   'County': 'Custer'},
#  {'datetime': '2022-10-17',
#   'tempmax': 70.8,
#   'tempmin': 39.0,
#   'temp': 53.0,
#   'humidity': 42.9,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.0,
#   'solarradiation': 186.9,
#   'solarenergy': 16.2,
#   'uvindex': 7.0,
#   'sunrise': '07:22:57',
#   'sunset': '18:30:01',
#   'County': 'Delta'},
#  {'datetime': '2022-10-17',
#   'tempmax': 61.3,
#   'tempmin': 34.1,
#   'temp': 47.1,
#   'humidity': 52.4,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 13.0,
#   'solarradiation': 139.3,
#   'solarenergy': 12.0,
#   'uvindex': 6.0,
#   'sunrise': '07:11:57',
#   'sunset': '18:17:08',
#   'County': 'Denver'},
#  {'datetime': '2022-10-17',
#   'tempmax': 58.0,
#   'tempmin': 34.8,
#   'temp': 45.9,
#   'humidity': 69.2,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 13.9,
#   'solarradiation': 161.4,
#   'solarenergy': 13.8,
#   'uvindex': 8.0,
#   'sunrise': '07:24:29',
#   'sunset': '18:33:50',
#   'County': 'Dolores'},
#  {'datetime': '2022-10-17',
#   'tempmax': 58.3,
#   'tempmin': 31.0,
#   'temp': 44.5,
#   'humidity': 59.2,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 14.1,
#   'solarradiation': 191.8,
#   'solarenergy': 16.6,
#   'uvindex': 7.0,
#   'sunrise': '07:11:40',
#   'sunset': '18:17:47',
#   'County': 'Douglas'},
#  {'datetime': '2022-10-17',
#   'tempmax': 64.1,
#   'tempmin': 28.9,
#   'temp': 44.8,
#   'humidity': 45.8,
#   'precipcover': 8.33,
#   'preciptype': ['rain', 'snow'],
#   'cloudcover': 0.8,
#   'solarradiation': 140.8,
#   'solarenergy': 12.2,
#   'uvindex': 6.0,
#   'sunrise': '07:19:04',
#   'sunset': '18:24:31',
#   'County': 'Eagle'},
#  {'datetime': '2022-10-17',
#   'tempmax': 59.4,
#   'tempmin': 26.1,
#   'temp': 42.2,
#   'humidity': 54.0,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 5.9,
#   'solarradiation': 172.3,
#   'solarenergy': 14.9,
#   'uvindex': 6.0,
#   'sunrise': '07:08:25',
#   'sunset': '18:14:34',
#   'County': 'Elbert'},
#  {'datetime': '2022-10-17',
#   'tempmax': 61.6,
#   'tempmin': 31.5,
#   'temp': 46.3,
#   'humidity': 54.3,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 11.5,
#   'solarradiation': 123.3,
#   'solarenergy': 10.6,
#   'uvindex': 6.0,
#   'sunrise': '07:09:33',
#   'sunset': '18:16:43',
#   'County': 'El Paso'},
#  {'datetime': '2022-10-17',
#   'tempmax': 59.4,
#   'tempmin': 34.4,
#   'temp': 46.3,
#   'humidity': 55.5,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 5.5,
#   'solarradiation': 185.1,
#   'solarenergy': 16.0,
#   'uvindex': 7.0,
#   'sunrise': '07:12:45',
#   'sunset': '18:20:41',
#   'County': 'Fremont'},
#  {'datetime': '2022-10-17',
#   'tempmax': 69.5,
#   'tempmin': 32.4,
#   'temp': 49.4,
#   'humidity': 45.7,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.0,
#   'solarradiation': 186.0,
#   'solarenergy': 15.9,
#   'uvindex': 6.0,
#   'sunrise': '07:23:54',
#   'sunset': '18:29:25',
#   'County': 'Garfield'},
#  {'datetime': '2022-10-17',
#   'tempmax': 45.1,
#   'tempmin': 28.1,
#   'temp': 35.5,
#   'humidity': 55.8,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 6.7,
#   'solarradiation': 257.2,
#   'solarenergy': 22.7,
#   'uvindex': 6.0,
#   'sunrise': '07:14:39',
#   'sunset': '18:19:37',
#   'County': 'Gilpin'},
#  {'datetime': '2022-10-17',
#   'tempmax': 55.4,
#   'tempmin': 22.6,
#   'temp': 38.4,
#   'humidity': 52.1,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 2.2,
#   'solarradiation': 177.3,
#   'solarenergy': 15.3,
#   'uvindex': 6.0,
#   'sunrise': '07:17:12',
#   'sunset': '18:21:36',
#   'County': 'Grand'},
#  {'datetime': '2022-10-17',
#   'tempmax': 62.6,
#   'tempmin': 25.5,
#   'temp': 44.1,
#   'humidity': 50.0,
#   'precipcover': 0.0,
#   'preciptype': None,
# ...
#   'tempmax': 38.4,
#   'tempmin': 14.4,
#   'temp': 26.3,
#   'humidity': 60.2,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.9,
#   'solarradiation': 73.5,
#   'solarenergy': 6.5,
#   'uvindex': 5.0,
#   'sunrise': '07:14:22',
#   'sunset': '16:50:34',
#   'County': 'Costilla'},
#  {'datetime': '2022-12-26',
#   'tempmax': 43.2,
#   'tempmin': 23.6,
#   'temp': 30.8,
#   'humidity': 76.3,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 23.9,
#   'solarradiation': 103.0,
#   'solarenergy': 8.9,
#   'uvindex': 5.0,
#   'sunrise': '07:10:47',
#   'sunset': '16:41:02',
#   'County': 'Crowley'},
#  {'datetime': '2022-12-26',
#   'tempmax': 42.1,
#   'tempmin': 22.3,
#   'temp': 30.4,
#   'humidity': 63.6,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 3.1,
#   'solarradiation': 110.9,
#   'solarenergy': 9.4,
#   'uvindex': 5.0,
#   'sunrise': '07:16:29',
#   'sunset': '16:48:01',
#   'County': 'Custer'},
#  {'datetime': '2022-12-26',
#   'tempmax': 44.4,
#   'tempmin': 22.3,
#   'temp': 31.6,
#   'humidity': 71.1,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.0,
#   'solarradiation': 73.7,
#   'solarenergy': 6.3,
#   'uvindex': 3.0,
#   'sunrise': '07:28:40',
#   'sunset': '16:55:46',
#   'County': 'Delta'},
#  {'datetime': '2022-12-26',
#   'tempmax': 48.9,
#   'tempmin': 27.0,
#   'temp': 37.5,
#   'humidity': 67.9,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 79.1,
#   'solarradiation': 69.6,
#   'solarenergy': 6.0,
#   'uvindex': 3.0,
#   'sunrise': '07:19:25',
#   'sunset': '16:41:08',
#   'County': 'Denver'},
#  {'datetime': '2022-12-26',
#   'tempmax': 46.1,
#   'tempmin': 25.7,
#   'temp': 33.8,
#   'humidity': 60.1,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.0,
#   'solarradiation': 113.1,
#   'solarenergy': 9.8,
#   'uvindex': 5.0,
#   'sunrise': '07:28:06',
#   'sunset': '17:01:39',
#   'County': 'Dolores'},
#  {'datetime': '2022-12-26',
#   'tempmax': 46.9,
#   'tempmin': 26.0,
#   'temp': 36.6,
#   'humidity': 66.1,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 68.0,
#   'solarradiation': 69.2,
#   'solarenergy': 6.0,
#   'uvindex': 4.0,
#   'sunrise': '07:18:17',
#   'sunset': '16:42:38',
#   'County': 'Douglas'},
#  {'datetime': '2022-12-26',
#   'tempmax': 43.8,
#   'tempmin': 25.9,
#   'temp': 33.0,
#   'humidity': 72.1,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 39.9,
#   'solarradiation': 61.0,
#   'solarenergy': 5.3,
#   'uvindex': 3.0,
#   'sunrise': '07:26:16',
#   'sunset': '16:48:47',
#   'County': 'Eagle'},
#  {'datetime': '2022-12-26',
#   'tempmax': 41.7,
#   'tempmin': 21.5,
#   'temp': 32.2,
#   'humidity': 78.9,
#   'precipcover': 12.5,
#   'preciptype': ['rain', 'snow'],
#   'cloudcover': 32.6,
#   'solarradiation': 101.7,
#   'solarenergy': 8.6,
#   'uvindex': 5.0,
#   'sunrise': '07:15:01',
#   'sunset': '16:39:27',
#   'County': 'Elbert'},
#  {'datetime': '2022-12-26',
#   'tempmax': 41.4,
#   'tempmin': 23.3,
#   'temp': 32.0,
#   'humidity': 73.7,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 53.9,
#   'solarradiation': 52.7,
#   'solarenergy': 4.6,
#   'uvindex': 3.0,
#   'sunrise': '07:15:13',
#   'sunset': '16:42:31',
#   'County': 'El Paso'},
#  {'datetime': '2022-12-26',
#   'tempmax': 41.7,
#   'tempmin': 26.9,
#   'temp': 33.3,
#   'humidity': 67.4,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 34.8,
#   'solarradiation': 111.5,
#   'solarenergy': 9.6,
#   'uvindex': 5.0,
#   'sunrise': '07:17:42',
#   'sunset': '16:47:11',
#   'County': 'Fremont'},
#  {'datetime': '2022-12-26',
#   'tempmax': 39.4,
#   'tempmin': 20.1,
#   'temp': 28.4,
#   'humidity': 77.9,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 25.1,
#   'solarradiation': 81.3,
#   'solarenergy': 7.0,
#   'uvindex': 4.0,
#   'sunrise': '07:31:03',
#   'sunset': '16:53:45',
#   'County': 'Garfield'},
#  {'datetime': '2022-12-26',
#   'tempmax': 29.9,
#   'tempmin': 21.3,
#   'temp': 25.6,
#   'humidity': 78.5,
#   'precipcover': 8.33,
#   'preciptype': ['snow'],
#   'cloudcover': 52.4,
#   'solarradiation': 206.9,
#   'solarenergy': 18.1,
#   'uvindex': 4.0,
#   'sunrise': '07:22:19',
#   'sunset': '16:43:26',
#   'County': 'Gilpin'},
#  {'datetime': '2022-12-26',
#   'tempmax': 33.4,
#   'tempmin': 19.7,
#   'temp': 28.2,
#   'humidity': 81.8,
#   'precipcover': 8.33,
#   'preciptype': ['rain', 'snow'],
#   'cloudcover': 60.3,
#   'solarradiation': 59.0,
#   'solarenergy': 5.2,
#   'uvindex': 3.0,
#   'sunrise': '07:25:23',
#   'sunset': '16:44:54',
#   'County': 'Grand'},
#  {'datetime': '2022-12-26',
#   'tempmax': 42.0,
#   'tempmin': 14.2,
#   'temp': 26.4,
#   'humidity': 72.0,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 3.8,
#   'solarradiation': 100.0,
#   'solarenergy': 8.7,
#   'uvindex': 4.0,
#   'sunrise': '07:24:57',
#   'sunset': '16:53:11',
#   'County': 'Gunnison'},
#  {'datetime': '2022-12-26',
#   'tempmax': 39.6,
#   'tempmin': 24.5,
#   'temp': 31.0,
#   'humidity': 58.4,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 2.7,
#   'solarradiation': 110.0,
#   'solarenergy': 9.5,
#   'uvindex': 5.0,
#   'sunrise': '07:23:42',
#   'sunset': '16:56:53',
#   'County': 'Hinsdale'},
#  {'datetime': '2022-12-26',
#   'tempmax': 36.8,
#   'tempmin': 19.9,
#   'temp': 28.7,
#   'humidity': 60.3,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 1.9,
#   'solarradiation': 120.7,
#   'solarenergy': 10.6,
#   'uvindex': 5.0,
#   'sunrise': '07:13:39',
#   'sunset': '16:47:32',
#   'County': 'Huerfano'},
#  {'datetime': '2022-12-26',
#   'tempmax': 34.0,
#   'tempmin': 27.6,
#   'temp': 31.0,
#   'humidity': 76.4,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 38.6,
#   'solarradiation': 87.2,
#   'solarenergy': 7.6,
#   'uvindex': 4.0,
#   'sunrise': '07:27:59',
#   'sunset': '16:44:10',
#   'County': 'Jackson'},
#  {'datetime': '2022-12-26',
#   'tempmax': 47.9,
#   'tempmin': 28.7,
#   'temp': 37.9,
#   'humidity': 66.5,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 65.8,
#   'solarradiation': 165.0,
#   'solarenergy': 14.6,
#   'uvindex': 3.0,
#   'sunrise': '07:20:21',
#   'sunset': '16:43:08',
#   'County': 'Jefferson'},
#  {'datetime': '2022-12-26',
#   'tempmax': 46.9,
#   'tempmin': 22.0,
#   'temp': 35.9,
#   'humidity': 64.2,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 38.0,
#   'solarradiation': 111.1,
#   'solarenergy': 9.5,
#   'uvindex': 5.0,
#   'sunrise': '07:06:51',
#   'sunset': '16:36:43',
#   'County': 'Kiowa'},
#  {'datetime': '2022-12-26',
#   'tempmax': 47.0,
#   'tempmin': 29.0,
#   'temp': 36.0,
#   'humidity': 59.0,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 17.6,
#   'solarradiation': 114.9,
#   'solarenergy': 9.7,
#   'uvindex': 5.0,
#   'sunrise': '07:08:56',
#   'sunset': '16:33:24',
#   'County': 'Kit Carson'},
#  {'datetime': '2022-12-26',
#   'tempmax': 38.1,
#   'tempmin': 17.2,
#   'temp': 27.5,
#   'humidity': 68.9,
#   'precipcover': 4.17,
#   'preciptype': ['snow'],
#   'cloudcover': 30.5,
#   'solarradiation': 100.0,
#   'solarenergy': 8.7,
#   'uvindex': 4.0,
#   'sunrise': '07:23:37',
#   'sunset': '16:48:42',
#   'County': 'Lake'},
#  {'datetime': '2022-12-26',
#   'tempmax': 46.4,
#   'tempmin': 18.3,
#   'temp': 30.8,
#   'humidity': 71.3,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.0,
#   'solarradiation': 96.7,
#   'solarenergy': 8.2,
#   'uvindex': 4.0,
#   'sunrise': '07:24:03',
#   'sunset': '17:00:11',
#   'County': 'La Plata'},
#  {'datetime': '2022-12-26',
#   'tempmax': 43.3,
#   'tempmin': 26.4,
#   'temp': 34.6,
#   'humidity': 78.4,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 23.7,
#   'solarradiation': 81.7,
#   'solarenergy': 7.0,
#   'uvindex': 4.0,
#   'sunrise': '07:24:36',
#   'sunset': '16:40:46',
#   'County': 'Larimer'},
#  {'datetime': '2022-12-26',
#   'tempmax': 49.5,
#   'tempmin': 16.4,
#   'temp': 34.3,
#   'humidity': 61.9,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.1,
#   'solarradiation': 106.5,
#   'solarenergy': 9.2,
#   'uvindex': 5.0,
#   'sunrise': '07:08:57',
#   'sunset': '16:44:55',
#   'County': 'Las Animas'},
#  {'datetime': '2022-12-26',
#   'tempmax': 41.9,
#   'tempmin': 21.3,
#   'temp': 32.4,
#   'humidity': 78.7,
#   'precipcover': 12.5,
#   'preciptype': ['rain', 'snow'],
#   'cloudcover': 32.1,
#   'solarradiation': 109.0,
#   'solarenergy': 9.5,
#   'uvindex': 5.0,
#   'sunrise': '07:11:38',
#   'sunset': '16:37:57',
#   'County': 'Lincoln'},
#  {'datetime': '2022-12-26',
#   'tempmax': 41.2,
#   'tempmin': 25.8,
#   'temp': 33.6,
#   'humidity': 77.5,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 6.2,
#   'solarradiation': 100.0,
#   'solarenergy': 8.7,
#   'uvindex': 4.0,
#   'sunrise': '07:15:14',
#   'sunset': '16:31:00',
#   'County': 'Logan'},
#  {'datetime': '2022-12-26',
#   'tempmax': 43.2,
#   'tempmin': 24.0,
#   'temp': 32.0,
#   'humidity': 73.0,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.0,
#   'solarradiation': 85.3,
#   'solarenergy': 7.3,
#   'uvindex': 4.0,
#   'sunrise': '07:31:31',
#   'sunset': '16:57:42',
#   'County': 'Mesa'},
#  {'datetime': '2022-12-26',
#   'tempmax': 34.1,
#   'tempmin': 22.4,
#   'temp': 27.9,
#   'humidity': 57.4,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 6.8,
#   'solarradiation': 109.9,
#   'solarenergy': 9.5,
#   'uvindex': 5.0,
#   'sunrise': '07:21:26',
#   'sunset': '16:55:32',
#   'County': 'Mineral'},
#  {'datetime': '2022-12-26',
#   'tempmax': 36.3,
#   'tempmin': 17.9,
#   'temp': 26.1,
#   'humidity': 82.9,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 36.5,
#   'solarradiation': 94.8,
#   'solarenergy': 8.1,
#   'uvindex': 4.0,
#   'sunrise': '07:35:13',
#   'sunset': '16:51:57',
#   'County': 'Moffat'},
#  {'datetime': '2022-12-26',
#   'tempmax': 48.5,
#   'tempmin': 21.9,
#   'temp': 33.2,
#   'humidity': 66.2,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.0,
#   'solarradiation': 98.2,
#   'solarenergy': 8.5,
#   'uvindex': 4.0,
#   'sunrise': '07:27:13',
#   'sunset': '17:03:04',
#   'County': 'Montezuma'},
#  {'datetime': '2022-12-26',
#   'tempmax': 43.8,
#   'tempmin': 21.6,
#   'temp': 30.7,
#   'humidity': 73.1,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.0,
#   'solarradiation': 86.3,
#   'solarenergy': 7.5,
#   'uvindex': 4.0,
#   'sunrise': '07:28:57',
#   'sunset': '16:58:40',
#   'County': 'Montrose'},
#  {'datetime': '2022-12-26',
#   'tempmax': 40.8,
#   'tempmin': 26.5,
#   'temp': 33.9,
#   'humidity': 76.1,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 15.4,
#   'solarradiation': 94.5,
#   'solarenergy': 8.3,
#   'uvindex': 5.0,
#   'sunrise': '07:16:39',
#   'sunset': '16:35:19',
#   'County': 'Morgan'},
#  {'datetime': '2022-12-26',
#   'tempmax': 45.5,
#   'tempmin': 21.2,
#   'temp': 31.1,
#   'humidity': 77.4,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 28.8,
#   'solarradiation': 103.3,
#   'solarenergy': 9.1,
#   'uvindex': 5.0,
#   'sunrise': '07:09:15',
#   'sunset': '16:42:01',
#   'County': 'Otero'},
#  {'datetime': '2022-12-26',
#   'tempmax': 42.8,
#   'tempmin': 24.9,
#   'temp': 32.4,
#   'humidity': 61.3,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.0,
#   'solarradiation': 67.5,
#   'solarenergy': 5.8,
#   'uvindex': 3.0,
#   'sunrise': '07:26:12',
#   'sunset': '16:57:27',
#   'County': 'Ouray'},
#  {'datetime': '2022-12-26',
#   'tempmax': 32.7,
#   'tempmin': 20.7,
#   'temp': 26.0,
#   'humidity': 62.3,
#   'precipcover': 4.17,
#   'preciptype': ['snow'],
#   'cloudcover': 13.9,
#   'solarradiation': 80.3,
#   'solarenergy': 6.9,
#   'uvindex': 4.0,
#   'sunrise': '07:20:50',
#   'sunset': '16:46:25',
#   'County': 'Park'},
#  {'datetime': '2022-12-26',
#   'tempmax': 41.0,
#   'tempmin': 24.8,
#   'temp': 34.0,
#   'humidity': 77.9,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 22.9,
#   'solarradiation': 79.5,
#   'solarenergy': 6.7,
#   'uvindex': 4.0,
#   'sunrise': '07:11:50',
#   'sunset': '16:28:26',
#   'County': 'Phillips'},
#  {'datetime': '2022-12-26',
#   'tempmax': 42.2,
#   'tempmin': 21.9,
#   'temp': 30.8,
#   'humidity': 70.9,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 44.8,
#   'solarradiation': 83.1,
#   'solarenergy': 7.1,
#   'uvindex': 4.0,
#   'sunrise': '07:25:56',
#   'sunset': '16:50:55',
#   'County': 'Pitkin'},
#  {'datetime': '2022-12-26',
#   'tempmax': 47.8,
#   'tempmin': 23.8,
#   'temp': 37.2,
#   'humidity': 61.0,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 39.4,
#   'solarradiation': 111.6,
#   'solarenergy': 9.6,
#   'uvindex': 5.0,
#   'sunrise': '07:04:09',
#   'sunset': '16:36:29',
#   'County': 'Prowers'},
#  {'datetime': '2022-12-26',
#   'tempmax': 46.8,
#   'tempmin': 19.3,
#   'temp': 30.7,
#   'humidity': 73.3,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 4.1,
#   'solarradiation': 93.1,
#   'solarenergy': 8.0,
#   'uvindex': 4.0,
#   'sunrise': '07:13:09',
#   'sunset': '16:44:17',
#   'County': 'Pueblo'},
#  {'datetime': '2022-12-26',
#   'tempmax': 36.9,
#   'tempmin': 14.1,
#   'temp': 24.6,
#   'humidity': 83.4,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 24.5,
#   'solarradiation': 91.1,
#   'solarenergy': 7.8,
#   'uvindex': 4.0,
#   'sunrise': '07:33:21',
#   'sunset': '16:53:47',
#   'County': 'Rio Blanco'},
#  {'datetime': '2022-12-26',
#   'tempmax': 37.6,
#   'tempmin': 20.6,
#   'temp': 28.0,
#   'humidity': 55.5,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 4.9,
#   'solarradiation': 83.4,
#   'solarenergy': 7.2,
#   'uvindex': 4.0,
#   'sunrise': '07:19:03',
#   'sunset': '16:54:05',
#   'County': 'Rio Grande'},
#  {'datetime': '2022-12-26',
#   'tempmax': 36.7,
#   'tempmin': 23.0,
#   'temp': 31.8,
#   'humidity': 85.2,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 62.3,
#   'solarradiation': 58.3,
#   'solarenergy': 5.0,
#   'uvindex': 3.0,
#   'sunrise': '07:30:03',
#   'sunset': '16:47:21',
#   'County': 'Routt'},
#  {'datetime': '2022-12-26',
#   'tempmax': 46.2,
#   'tempmin': 25.3,
#   'temp': 33.7,
#   'humidity': 56.6,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 3.2,
#   'solarradiation': 110.0,
#   'solarenergy': 9.5,
#   'uvindex': 5.0,
#   'sunrise': '07:19:47',
#   'sunset': '16:51:42',
#   'County': 'Saguache'},
#  {'datetime': '2022-12-26',
#   'tempmax': 43.2,
#   'tempmin': 25.9,
#   'temp': 33.1,
#   'humidity': 57.9,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.0,
#   'solarradiation': 105.5,
#   'solarenergy': 9.1,
#   'uvindex': 5.0,
#   'sunrise': '07:24:46',
#   'sunset': '16:58:07',
#   'County': 'San Juan'},
#  {'datetime': '2022-12-26',
#   'tempmax': 43.8,
#   'tempmin': 24.6,
#   'temp': 32.5,
#   'humidity': 61.8,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.0,
#   'solarradiation': 90.3,
#   'solarenergy': 7.7,
#   'uvindex': 5.0,
#   'sunrise': '07:28:27',
#   'sunset': '17:00:30',
#   'County': 'San Miguel'},
#  {'datetime': '2022-12-26',
#   'tempmax': 39.9,
#   'tempmin': 23.4,
#   'temp': 33.2,
#   'humidity': 77.4,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 22.5,
#   'solarradiation': 100.4,
#   'solarenergy': 8.6,
#   'uvindex': 4.0,
#   'sunrise': '07:12:45',
#   'sunset': '16:27:36',
#   'County': 'Sedgwick'},
#  {'datetime': '2022-12-26',
#   'tempmax': 26.7,
#   'tempmin': 17.9,
#   'temp': 22.4,
#   'humidity': 80.2,
#   'precipcover': 12.5,
#   'preciptype': ['snow'],
#   'cloudcover': 55.6,
#   'solarradiation': 79.5,
#   'solarenergy': 6.9,
#   'uvindex': 4.0,
#   'sunrise': '07:24:01',
#   'sunset': '16:46:36',
#   'County': 'Summit'},
#  {'datetime': '2022-12-26',
#   'tempmax': 40.7,
#   'tempmin': 24.4,
#   'temp': 32.3,
#   'humidity': 70.8,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 35.0,
#   'solarradiation': 99.3,
#   'solarenergy': 8.5,
#   'uvindex': 5.0,
#   'sunrise': '07:17:58',
#   'sunset': '16:45:00',
#   'County': 'Teller'},
#  {'datetime': '2022-12-26',
#   'tempmax': 39.2,
#   'tempmin': 25.3,
#   'temp': 34.1,
#   'humidity': 70.7,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 12.9,
#   'solarradiation': 95.6,
#   'solarenergy': 8.2,
#   'uvindex': 4.0,
#   'sunrise': '07:13:21',
#   'sunset': '16:33:50',
#   'County': 'Washington'},
#  {'datetime': '2022-12-26',
#   'tempmax': 41.8,
#   'tempmin': 20.0,
#   'temp': 31.6,
#   'humidity': 82.7,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 30.4,
#   'solarradiation': 94.5,
#   'solarenergy': 8.3,
#   'uvindex': 5.0,
#   'sunrise': '07:19:52',
#   'sunset': '16:36:43',
#   'County': 'Weld'},
#  {'datetime': '2022-12-26',
#   'tempmax': 42.4,
#   'tempmin': 24.8,
#   'temp': 34.6,
#   'humidity': 71.8,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 17.8,
#   'solarradiation': 88.5,
#   'solarenergy': 7.5,
#   'uvindex': 5.0,
#   'sunrise': '07:10:19',
#   'sunset': '16:30:35',
#   'County': 'Yuma'}]

# %%
#Convert to DF and confirm correct shape
part4_df = pd.DataFrame(weather_data)
part4_df.shape
# Out:
# (832, 14)

# %%
#Convert to CSV
part4_df.to_csv('C:/Users/adina/Desktop/Classwork/Project 1/Project-1/2022Pt4.csv',index=False)

# %%
#Combine DFs and convert to CSV of all data
full2022_df = pd.concat([part1_df,part2_df,part3_df,part4_df])
full2022_df.to_csv('C:/Users/adina/Desktop/Classwork/Project 1/Project-1/2022Mondays.csv',index=False)

# %% [markdown]
# ***
# ### Testing/development cells

# %%
#DON'T NEED THIS
# Iterate through the DataFrame
for index, row in counties_weather_df.iterrows():
    
    # Get latitude, longitude from the DataFrame
    latitude = row["Latitude"]
    longitude = row["Longitude"]
    
    # Set base URL
#     base_url = f'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/{latitude},{longitude}/{date}/{date}?key={api_key}&contentType=json&include=days&elements=cloudcover,datetime,solarradiation,solarenergy,tempmax,tempmin,temp,humidity,precipcover,preciptype,uvindex,sunrise,sunset'
           
    # Make an API request and convert to JSON
    response = requests.get(base_url,params=params).json()
    
    # Grab the first airport from the results and store the details in the DataFrame
    try:
        counties_weather_df.loc[index, "Date"] = response['days'][0]['datetime']
        counties_weather_df.loc[index, "Max Temp"] = response['days'][0]['tempmax']
        counties_weather_df.loc[index, "Min Temp"] = response['days'][0]['tempmin']
        counties_weather_df.loc[index, "Avg Temp"] = response['days'][0]['temp']
        counties_weather_df.loc[index, "Humidity"] = response['days'][0]['humidity']
        counties_weather_df.loc[index, "Precip Cover"] = response['days'][0]['precipcover']
        counties_weather_df.loc[index, "Precip Type"] = response['days'][0]['preciptype']
        counties_weather_df.loc[index, "Cloud Cover"] = response['days'][0]['cloudcover']
        counties_weather_df.loc[index, "Solar Radiation"] = response['days'][0]['solarradiation']
        counties_weather_df.loc[index, "Solar Energy"] = response['days'][0]['solarenergy']
        counties_weather_df.loc[index, "UV Index"] = response['days'][0]['uvindex']
        counties_weather_df.loc[index, "Sunrise"] = response['days'][0]['sunrise']
        counties_weather_df.loc[index, "Sunset"] = response['days'][0]['sunset']
    except:
        pass

# Display sample data
counties_weather_df.head()

# %%
#Test request
data = requests.get('https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/39.874325,-104.331872/2020-10-01/2020-10-01?key=LH73CB26GBPR44YGBTZVU2LDX&contentType=json&include=days&elements=cloudcover,datetime,solarradiation,solarenergy,tempmax,tempmin,temp,humidity,precipcover,preciptype,uvindex,sunrise,sunset').json()
data
# Out:
# {'queryCost': 1,
#  'latitude': 39.874325,
#  'longitude': -104.331872,
#  'resolvedAddress': '39.874325,-104.331872',
#  'address': '39.874325,-104.331872',
#  'timezone': 'America/Denver',
#  'tzoffset': -6.0,
#  'days': [{'datetime': '2020-10-01',
#    'tempmax': 66.7,
#    'tempmin': 40.5,
#    'temp': 52.9,
#    'humidity': 39.1,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'cloudcover': 48.9,
#    'solarradiation': 370.4,
#    'solarenergy': 17.3,
#    'uvindex': 7.0,
#    'sunrise': '06:54:06',
#    'sunset': '18:38:49'}]}

# %%
#TEST DF
test_df = counties_weather_df.copy()
test_df = test_df[:5]
test_df
# Out:
#    FIPS     County  County Seat(s) Population (2010) Land Area km2  \
# 0  8001      Adams        Brighton           441,603      3,024.21
# 1  8003    Alamosa         Alamosa            15,445      1,871.64
# 2  8005   Arapahoe       Littleton           572,003      2,067.07
# 3  8007  Archuleta  Pagosa Springs            12,084      3,496.94
# 4  8009       Baca     Springfield             3,788      6,617.33
#
#   Land Area mi2  Water Area km2  Water Area mi2 Total Area km2 Total Area mi2  \
# 0      1,167.65          42.070          16.243       3,066.28       1,183.90
# 1       722.643           1.808           0.698       1,873.45        723.341
# 2         798.1          19.004           7.337       2,086.07        805.437
# 3      1,350.18          13.828           5.339       3,510.77       1,355.51
# 4      2,554.97           6.142           2.372       6,623.48       2,557.34
#
#    ...  Avg Temp  Humidity Precip Cover Precip Type Cloud Cover  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   Solar Radiation Solar Energy UV Index Sunrise Sunset
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 25 columns]

# %%
#DON'T NEED THIS
#testing for loop creating dataframes

# for index, row in counties_weather_df.iterrows():
for index, row in test_df.iterrows():
    
# Get latitude, longitude from the DataFrame
    latitude = 39.874325
    longitude = -104.331872
    date = '2020-10-02'
    api_key = adina_api_key

        # Set base URL
    base_url = f'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/{latitude},{longitude}/{date}/{date}?key={api_key}&contentType=json&include=days&elements=cloudcover,datetime,solarradiation,solarenergy,tempmax,tempmin,temp,humidity,precipcover,preciptype,uvindex,sunrise,sunset'

        # Make an API request and convert to JSON
    response = requests.get(base_url).json()

        # Grab the first airport from the results and store the details in the DataFrame
    try:
        test_df.loc[index, "Date"] = response['days'][0]['datetime']
        test_df.loc[index, "Max Temp"] = response['days'][0]['tempmax']
        test_df.loc[index, "Min Temp"] = response['days'][0]['tempmin']
        test_df.loc[index, "Avg Temp"] = response['days'][0]['temp']
        test_df.loc[index, "Humidity"] = response['days'][0]['humidity']
        test_df.loc[index, "Precip Cover"] = response['days'][0]['precipcover']
        test_df.loc[index, "Precip Type"] = response['days'][0]['preciptype']
        test_df.loc[index, "Cloud Cover"] = response['days'][0]['cloudcover']
        test_df.loc[index, "Solar Radiation"] = response['days'][0]['solarradiation']
        test_df.loc[index, "Solar Energy"] = response['days'][0]['solarenergy']
        test_df.loc[index, "UV Index"] = response['days'][0]['uvindex']
        test_df.loc[index, "Sunrise"] = response['days'][0]['sunrise']
        test_df.loc[index, "Sunset"] = response['days'][0]['sunset']
    except:
        pass


test_df
# Out:
#    FIPS     County  County Seat(s) Population (2010) Land Area km2  \
# 0  8001      Adams        Brighton           441,603      3,024.21
# 1  8003    Alamosa         Alamosa            15,445      1,871.64
# 2  8005   Arapahoe       Littleton           572,003      2,067.07
# 3  8007  Archuleta  Pagosa Springs            12,084      3,496.94
# 4  8009       Baca     Springfield             3,788      6,617.33
#
#   Land Area mi2  Water Area km2  Water Area mi2 Total Area km2 Total Area mi2  \
# 0      1,167.65          42.070          16.243       3,066.28       1,183.90
# 1       722.643           1.808           0.698       1,873.45        723.341
# 2         798.1          19.004           7.337       2,086.07        805.437
# 3      1,350.18          13.828           5.339       3,510.77       1,355.51
# 4      2,554.97           6.142           2.372       6,623.48       2,557.34
#
#    ...  Avg Temp  Humidity Precip Cover Precip Type Cloud Cover  \
# 0  ...      60.1      30.8          0.0        None        58.9
# 1  ...      60.1      30.8          0.0        None        58.9
# 2  ...      60.1      30.8          0.0        None        58.9
# 3  ...      60.1      30.8          0.0        None        58.9
# 4  ...      60.1      30.8          0.0        None        58.9
#
#   Solar Radiation Solar Energy UV Index   Sunrise    Sunset
# 0           341.8         15.9      7.0  06:55:05  18:37:12
# 1           341.8         15.9      7.0  06:55:05  18:37:12
# 2           341.8         15.9      7.0  06:55:05  18:37:12
# 3           341.8         15.9      7.0  06:55:05  18:37:12
# 4           341.8         15.9      7.0  06:55:05  18:37:12
#
# [5 rows x 25 columns]

# %%
#MODIFY THIS FOR SCALING
#testing for loop creating dictionary

weather_data = []

# for index, row in counties_weather_df.iterrows():
for index, row in test_df.iterrows():
    
# Get latitude, longitude from the DataFrame
    latitude = row['Latitude']
    longitude = row['Longitude']
    date = '2020-10-02'
    api_key = adina_api_key
    county = row['County']

        # Set base URL
    base_url = f'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/{latitude},{longitude}/{date}/{date}?key={api_key}&contentType=json&include=days&elements=cloudcover,datetime,solarradiation,solarenergy,tempmax,tempmin,temp,humidity,precipcover,preciptype,uvindex,sunrise,sunset'

        # Make an API request and convert to JSON
    response = requests.get(base_url).json()
    
    try:
        weather_dict = response['days'][0]
        weather_dict['County'] = county
        weather_data.append(weather_dict)
        
        # Grab the first airport from the results and store the details in the DataFrame
#     try:
# #         weather_data[county][date] = response['days'][0]['datetime']
# #         test_df.loc[index, "Max Temp"] = response['days'][0]['tempmax']
# #         test_df.loc[index, "Min Temp"] = response['days'][0]['tempmin']
# #         test_df.loc[index, "Avg Temp"] = response['days'][0]['temp']
# #         test_df.loc[index, "Humidity"] = response['days'][0]['humidity']
# #         test_df.loc[index, "Precip Cover"] = response['days'][0]['precipcover']
# #         test_df.loc[index, "Precip Type"] = response['days'][0]['preciptype']
# #         test_df.loc[index, "Cloud Cover"] = response['days'][0]['cloudcover']
# #         test_df.loc[index, "Solar Radiation"] = response['days'][0]['solarradiation']
# #         test_df.loc[index, "Solar Energy"] = response['days'][0]['solarenergy']
# #         test_df.loc[index, "UV Index"] = response['days'][0]['uvindex']
# #         test_df.loc[index, "Sunrise"] = response['days'][0]['sunrise']
# #         test_df.loc[index, "Sunset"] = response['days'][0]['sunset']
    except:
        pass


weather_data
# Out:
# [{'datetime': '2020-10-02',
#   'tempmax': 73.3,
#   'tempmin': 45.7,
#   'temp': 60.1,
#   'humidity': 30.8,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 58.9,
#   'solarradiation': 341.8,
#   'solarenergy': 15.9,
#   'uvindex': 7.0,
#   'sunrise': '06:55:05',
#   'sunset': '18:37:12',
#   'County': 'Adams'},
#  {'datetime': '2020-10-02',
#   'tempmax': 70.7,
#   'tempmin': 30.7,
#   'temp': 50.6,
#   'humidity': 40.3,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.0,
#   'solarradiation': 371.7,
#   'solarenergy': 16.2,
#   'uvindex': 7.0,
#   'sunrise': '07:00:01',
#   'sunset': '18:43:57',
#   'County': 'Alamosa'},
#  {'datetime': '2020-10-02',
#   'tempmax': 72.8,
#   'tempmin': 46.1,
#   'temp': 59.8,
#   'humidity': 30.7,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 59.0,
#   'solarradiation': 257.9,
#   'solarenergy': 11.9,
#   'uvindex': 6.0,
#   'sunrise': '06:54:59',
#   'sunset': '18:37:18',
#   'County': 'Arapahoe'},
#  {'datetime': '2020-10-02',
#   'tempmax': 69.8,
#   'tempmin': 33.9,
#   'temp': 52.5,
#   'humidity': 27.2,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.4,
#   'solarradiation': 367.3,
#   'solarenergy': 31.9,
#   'uvindex': 5.0,
#   'sunrise': '07:04:56',
#   'sunset': '18:49:09',
#   'County': 'Archuleta'},
#  {'datetime': '2020-10-02',
#   'tempmax': 82.1,
#   'tempmin': 43.1,
#   'temp': 60.7,
#   'humidity': 32.5,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 0.0,
#   'solarradiation': 367.0,
#   'solarenergy': 17.1,
#   'uvindex': 7.0,
#   'sunrise': '06:46:54',
#   'sunset': '18:31:04',
#   'County': 'Baca'}]

# %%
#DON'T NEED THIS - WILL BE CREATING DATAFRAMES WITH JUST WEATHER DATA AND THEN MERGING/CONCATENATING
#Creating new DF for county weather data
counties_weather_df = counties_df.copy()
counties_weather_df[['Date','Max Temp','Min Temp','Avg Temp','Humidity','Precip Cover','Precip Type','Cloud Cover','Solar Radiation','Solar Energy','UV Index','Sunrise','Sunset']] = ''
counties_weather_df
# Out:
#     FIPS      County  County Seat(s) Population (2010) Land Area km2  \
# 0   8001       Adams        Brighton           441,603      3,024.21
# 1   8003     Alamosa         Alamosa            15,445      1,871.64
# 2   8005    Arapahoe       Littleton           572,003      2,067.07
# 3   8007   Archuleta  Pagosa Springs            12,084      3,496.94
# 4   8009        Baca     Springfield             3,788      6,617.33
# ..   ...         ...             ...               ...           ...
# 59  8117      Summit    Breckenridge            27,994      1,575.64
# 60  8119      Teller   Cripple Creek            23,350      1,442.77
# 61  8121  Washington           Akron             4,814      6,521.67
# 62  8123        Weld         Greeley           252,825     10,326.90
# 63  8125        Yuma            Wray            10,043      6,123.78
#
#    Land Area mi2  Water Area km2  Water Area mi2 Total Area km2  \
# 0       1,167.65          42.070          16.243       3,066.28
# 1        722.643           1.808           0.698       1,873.45
# 2          798.1          19.004           7.337       2,086.07
# 3       1,350.18          13.828           5.339       3,510.77
# 4       2,554.97           6.142           2.372       6,623.48
# ..           ...             ...             ...            ...
# 59       608.358          28.283          10.920       1,603.92
# 60       557.055           4.945           1.909       1,447.71
# 61      2,518.03          15.207           5.872       6,536.88
# 62      3,987.24          76.554          29.558      10,403.45
# 63      2,364.41          11.135           4.299       6,134.92
#
#    Total Area mi2  ...  Avg Temp  Humidity Precip Cover Precip Type  \
# 0        1,183.90  ...
# 1         723.341  ...
# 2         805.437  ...
# 3        1,355.51  ...
# 4        2,557.34  ...
# ..            ...  ...       ...       ...          ...         ...
# 59        619.278  ...
# 60        558.964  ...
# 61       2,523.90  ...
# 62       4,016.80  ...
# 63       2,368.70  ...
#
#    Cloud Cover Solar Radiation Solar Energy UV Index Sunrise Sunset
# 0
# 1
# 2
# 3
# 4
# ..         ...             ...          ...      ...     ...    ...
# 59
# 60
# 61
# 62
# 63
#
# [64 rows x 25 columns]

# %%
#TEST DF OUTPUT
test_new_df = pd.DataFrame(weather_data)
test_new_df
# Out:
#      datetime  tempmax  tempmin  temp  humidity  precipcover preciptype  \
# 0  2020-10-02     73.3     45.7  60.1      30.8          0.0       None
# 1  2020-10-02     70.7     30.7  50.6      40.3          0.0       None
# 2  2020-10-02     72.8     46.1  59.8      30.7          0.0       None
# 3  2020-10-02     69.8     33.9  52.5      27.2          0.0       None
# 4  2020-10-02     82.1     43.1  60.7      32.5          0.0       None
#
#    cloudcover  solarradiation  solarenergy  uvindex   sunrise    sunset  \
# 0        58.9           341.8         15.9      7.0  06:55:05  18:37:12
# 1         0.0           371.7         16.2      7.0  07:00:01  18:43:57
# 2        59.0           257.9         11.9      6.0  06:54:59  18:37:18
# 3         0.4           367.3         31.9      5.0  07:04:56  18:49:09
# 4         0.0           367.0         17.1      7.0  06:46:54  18:31:04
#
#       County
# 0      Adams
# 1    Alamosa
# 2   Arapahoe
# 3  Archuleta
# 4       Baca

# %%
#DON'T NEED THIS - CREATING CODE FOR DICTIONARIES
weather_data = []
weather_dict = response['days'][0]
weather_dict['County'] = 'Denver'
weather_data.append(weather_dict)
weather_data
# Out:
# [{'datetime': '2020-10-02',
#   'tempmax': 73.3,
#   'tempmin': 45.7,
#   'temp': 60.1,
#   'humidity': 30.8,
#   'precipcover': 0.0,
#   'preciptype': None,
#   'cloudcover': 58.9,
#   'solarradiation': 341.8,
#   'solarenergy': 15.9,
#   'uvindex': 7.0,
#   'sunrise': '06:55:05',
#   'sunset': '18:37:12',
#   'County': 'Denver'}]
